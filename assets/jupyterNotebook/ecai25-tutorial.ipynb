# %% [markdown]
# # **Neural Networks Based on Differential Equations: From Physics-Informed Neural Networks to Neural ODEs**
#
# ### **Tutorial @ The Machine Learning and Principles and Practice of Knowledge Discovery in Databases - ECML PKDD 2025**
#
# #### **Cecília Coelho and Luís Ferrás**
#
# #### **Go to [website][Website]**
#
# [Website]: https://nnsdestutorial.github.io/

# %% [markdown]
# # --------------------------------------------------------

# %% [markdown]
# # Differential Equations Basics (Part I)

# %% [markdown]
# #### Numerical solution of a simple ODE using the explicit Euler method
#
#
# The differential equation $\dfrac{df(t)}{dt}=e^{−t}$ with initial condition $f(0)=−1$ has the exact solution $f(t)=−e^{−t}$. Approximate the solution to this initial value problem between 0 and 1 in increments of 0.1 using the **Explicit Euler Formula**. Plot the difference between the approximated solution and the exact solution.
#
#
#
# Play with the **solver**, **model parameters** and the **number of mesh elements**.

# %%
import numpy as np
import matplotlib.pyplot as plt

#plt.style.use('seaborn-poster')
# %matplotlib inline

# Define parameters
f = lambda t, s: np.exp(-t) # ODE
h = 0.1 # Step size
t = np.arange(0, 1 + h, h) # Numerical grid
s0 = -1 # Initial Condition

# Explicit Euler Method
s = np.zeros(len(t))
s[0] = s0

for i in range(0, len(t) - 1):
    s[i + 1] = s[i] + h*f(t[i], s[i])

plt.figure(figsize = (6, 5))
plt.plot(t, s, 'bo--', label='Approximate')
plt.plot(t, -np.exp(-t), 'g', label='Exact')
plt.title('Approximate and Exact Solution \
for Simple ODE')
plt.xlabel('t')
plt.ylabel('f(t)')
plt.grid()
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ## Differential Equations Basics (Part II)

# %% [markdown]
# #### Logistic Growth of a Population of Organisms
#
# Consider a population of organisms that follows a logistic growth. The population size $P(t)$ at time $t$ is governed by the following differential equation:
#             \begin{equation}
#              P'(t) = r P(t) \left(1 - \frac{P(t)}{K}\right), \quad P(t_0) = 100,
#             \end{equation}
#             where $r$ is the growth rate, and $K$ is the carrying capacity of the environment. Consider $r=0.1, K=1000$. Also, consider a mesh of 200 points.
#
#
#
# Play with the **solver**, **model parameters** and the **number of mesh elements**.

# %% [markdown]
# ##### First, try to implement $P'(t) = r P(t)$

# %%
import numpy as np
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt

# %%
r = 0.5
y0 = [100]
t = np.linspace(0, 5, 20)

def ODE(t, y):
    return r * y

sol = solve_ivp(ODE, [0, 5], y0, t_eval=t)

plt.figure(figsize = (6, 5))
plt.plot(sol.t.T, sol.y.T,'bo--')
plt.plot(t, y0*np.exp(r*t), 'g', label='Exact')
plt.xlabel('t')
plt.ylabel('P(t)')
plt.grid()
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ##### Now try to implement $P'(t) = r P(t) \left(1 - \frac{P(t)}{K}\right)$

# %%
r = 2
K = 100
y0 = 10
t = np.linspace(0, 20, 200)

def ODE(t, y):
    return r * y * (1- y/K)

sol = solve_ivp(ODE, [0, 20], [y0], t_eval=t)

plt.figure(figsize = (6, 5))
plt.plot(sol.t.T, sol.y.T,'bo--')
plt.plot(t, (K*y0*np.exp(r*t))/(K+y0*(np.exp(r*t)-1)), 'g', label='Exact')
plt.xlabel('t')
plt.ylabel('P(t)')
plt.show()

# %% [markdown]
# # --------------------------------------------------------

# %% [markdown]
# ## Physics-Informed Neural Networks

# %% [markdown]
#  Consider the 1D Burger's Equation with Dirichlet boundary conditions and $\lambda_1=1, \lambda_2=\frac{0.01}{\pi}$:
#             $$
#              \begin{align*}
#                     \frac{\partial u}{\partial t} + u \frac{\partial u}{\partial x} - \frac{0.01}{\pi} \frac{\partial^2u}{\partial x^2} = 0, \quad x\in [-1,1], t\in [0,1], \\
#                     u(0,x) = -\sin(\pi x),\\
#                     u(t,-1) = u(t,1) = 0.
#                 \end{align*}
#             $$

# %%
# !pip install torch
# !pip install git+https://github.com/lululxvi/deepxde
# !pip install tensorflow
# Out:
# zsh:1: command not found: pip
# zsh:1: command not found: pip
# zsh:1: command not found: pip

# %%
import deepxde as dde
import matplotlib.pyplot as plt
import numpy as np
from scipy import integrate
import tensorflow as tf
from scipy import integrate
import torch
# Out:
# Using backend: pytorch
# Other supported backends: tensorflow.compat.v1, tensorflow, jax, paddle.
# paddle supports more examples now and is recommended.

# %% [markdown]
# ### Data-driven solutions

# %% [markdown]
# **Problem:** *Given fixed model parameters $\lambda$, what can be said about the unknown $u(t, x)$?*
#
# PINNs approximate the solution $u(x)$ using a neural network $\hat{u}(x; \boldsymbol{\theta})$, where $\boldsymbol{\theta}$ represents the network parameters. The PINN is trained to fit the data and satisfy the PDE

# %% [markdown]
# #### 1D Burger's Equation

# %% [markdown]
# **Hands-on**
#
# What happens if we change the number of training points inside the domain? What about in the inital and boundary conditions?

# %%
# tensorflow

def gen_testdata():
    data = np.load("Burgers.npz")
    t, x, exact = data["t"], data["x"], data["usol"].T
    xx, tt = np.meshgrid(x, t)
    X = np.vstack((np.ravel(xx), np.ravel(tt))).T
    y = exact.flatten()[:, None]
    return X, y


def pde(x, y):
    dy_x = dde.grad.jacobian(y, x, i=0, j=0)
    dy_t = dde.grad.jacobian(y, x, i=0, j=1)
    dy_xx = dde.grad.hessian(y, x, i=0, j=0)
    return dy_t + y * dy_x - 0.01 / np.pi * dy_xx


geom = dde.geometry.Interval(-1, 1)
timedomain = dde.geometry.TimeDomain(0, 1)
geomtime = dde.geometry.GeometryXTime(geom, timedomain)

bc = dde.icbc.DirichletBC(geomtime, lambda x: 0, lambda _, on_boundary: on_boundary)
ic = dde.icbc.IC(
    geomtime, lambda x: -np.sin(np.pi * x[:, 0:1]), lambda _, on_initial: on_initial
)

data = dde.data.TimePDE(
    geomtime, pde, [bc, ic], num_domain=2540, num_boundary=80, num_initial=160
)
net = dde.nn.FNN([2] + [20] * 3 + [1], "tanh", "Glorot normal")
model = dde.Model(data, net)

model.compile("adam", lr=1e-3)
model.train(iterations=15000)
model.compile("L-BFGS")
losshistory, train_state = model.train()
dde.saveplot(losshistory, train_state, issave=True, isplot=True)

X, y_true = gen_testdata()
y_pred = model.predict(X)
f = model.predict(X, operator=pde)
print("Mean residual:", np.mean(np.absolute(f)))
print("L2 relative error:", dde.metrics.l2_relative_error(y_true, y_pred))
np.savetxt("test.dat", np.hstack((X, y_true, y_pred)))
# Out:
# Compiling model...
# 'compile' took 0.431594 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 0         [3.66e-02, 3.75e-01, 1.11e+00]    [3.66e-02, 3.75e-01, 1.11e+00]    []
# 1000      [4.58e-02, 3.65e-03, 7.05e-02]    [4.58e-02, 3.65e-03, 7.05e-02]    []
# 2000      [3.73e-02, 2.65e-04, 4.92e-02]    [3.73e-02, 2.65e-04, 4.92e-02]    []
# 3000      [3.08e-02, 7.78e-05, 4.15e-02]    [3.08e-02, 7.78e-05, 4.15e-02]    []
# 4000      [2.08e-02, 5.33e-05, 2.11e-02]    [2.08e-02, 5.33e-05, 2.11e-02]    []
# 5000      [1.39e-02, 5.43e-05, 9.76e-03]    [1.39e-02, 5.43e-05, 9.76e-03]    []
# 6000      [9.35e-03, 3.16e-05, 5.71e-03]    [9.35e-03, 3.16e-05, 5.71e-03]    []
# 7000      [1.20e-02, 3.93e-05, 4.77e-03]    [1.20e-02, 3.93e-05, 4.77e-03]    []
# 8000      [5.19e-03, 5.85e-06, 3.63e-03]    [5.19e-03, 5.85e-06, 3.63e-03]    []
# 9000      [4.01e-03, 2.60e-06, 3.17e-03]    [4.01e-03, 2.60e-06, 3.17e-03]    []
# 10000     [3.27e-03, 2.65e-06, 2.91e-03]    [3.27e-03, 2.65e-06, 2.91e-03]    []
# 11000     [2.79e-03, 3.69e-06, 2.72e-03]    [2.79e-03, 3.69e-06, 2.72e-03]    []
# 12000     [2.48e-03, 3.56e-06, 2.55e-03]    [2.48e-03, 3.56e-06, 2.55e-03]    []
# 13000     [2.41e-03, 2.44e-06, 2.20e-03]    [2.41e-03, 2.44e-06, 2.20e-03]    []
# 14000     [1.61e-03, 1.73e-06, 9.17e-04]    [1.61e-03, 1.73e-06, 9.17e-04]    []
# 15000     [1.46e-03, 1.42e-06, 8.45e-04]    [1.46e-03, 1.42e-06, 8.45e-04]    []
#
# Best model at step 15000:
#   train loss: 2.31e-03
#   test loss: 2.31e-03
#   test metric: []
#
# 'train' took 28.772258 s
#
# Compiling model...
# 'compile' took 0.000081 s
#
# Training model...
#
# Step      Train loss                        Test loss                         Test metric
# 15000     [1.46e-03, 1.42e-06, 8.45e-04]    [1.46e-03, 1.42e-06, 8.45e-04]    []
# 16000     [1.73e-04, 1.71e-06, 8.09e-05]    [1.73e-04, 1.71e-06, 8.09e-05]    []
# 17000     [6.70e-05, 3.66e-07, 2.48e-05]    [6.70e-05, 3.66e-07, 2.48e-05]    []
# 18000     [3.39e-05, 2.00e-07, 7.59e-06]    [3.39e-05, 2.00e-07, 7.59e-06]    []
# 19000     [1.94e-05, 9.00e-08, 2.88e-06]    [1.94e-05, 9.00e-08, 2.88e-06]    []
# 20000     [1.24e-05, 6.70e-08, 1.28e-06]    [1.24e-05, 6.70e-08, 1.28e-06]    []
# 21000     [8.68e-06, 5.90e-08, 9.33e-07]    [8.68e-06, 5.90e-08, 9.33e-07]    []
# 22000     [6.46e-06, 3.40e-08, 5.64e-07]    [6.46e-06, 3.40e-08, 5.64e-07]    []
# 23000     [4.61e-06, 4.69e-08, 5.19e-07]    [4.61e-06, 4.69e-08, 5.19e-07]    []
# 23288     [4.36e-06, 3.52e-08, 4.83e-07]    [4.36e-06, 3.52e-08, 4.83e-07]    []
#
# Best model at step 23288:
#   train loss: 4.88e-06
#   test loss: 4.88e-06
#   test metric: []
#
# 'train' took 20.413186 s
#
# Saving loss history to /Users/ceciliacoelho/Downloads/jupyterNotebook/loss.dat ...
# Saving training data to /Users/ceciliacoelho/Downloads/jupyterNotebook/train.dat ...
# Saving test data to /Users/ceciliacoelho/Downloads/jupyterNotebook/test.dat ...
# Mean residual: 0.005095318
# L2 relative error: 0.01596892934749536

# %% [markdown]
# #### Lotka-Volterra

# %% [markdown]
# **Hands-on**
#
# Use PINNs to approximate the solution of the following Lotka-Volterra problem to know how the population of rabbits and foxes change over time in a system:
#                 $$\begin{align*}
#                     \dfrac{dr}{dt}=\dfrac{R}{U}(2Ur - 0.04U^2rf), \quad \dfrac{df}{dt}=\dfrac{R}{U}(0.002U^2rf - 1.06Uf), \\
#                     r(0)= \dfrac{100}{U}, \quad f(0)=\dfrac{15}{U}
#                 \end{align*}$$
#                 with $U=200$ and $R=20$.

# %%
# torch

ub = 200
rb = 20


def func(t, r):
    x, y = r
    dx_t = 1 / ub * rb * (2.0 * ub * x - 0.04 * ub * x * ub * y)
    dy_t = 1 / ub * rb * (0.02 * ub * x * ub * y - 1.06 * ub * y)
    return dx_t, dy_t


def gen_truedata():
    t = np.linspace(0, 1, 100)

    sol = integrate.solve_ivp(func, (0, 10), (100 / ub, 15 / ub), t_eval=t)
    x_true, y_true = sol.y
    x_true = x_true.reshape(100, 1)
    y_true = y_true.reshape(100, 1)

    return x_true, y_true


def ode_system(x, y):
    r = y[:, 0:1]
    p = y[:, 1:2]
    dr_t = dde.grad.jacobian(y, x, i=0)
    dp_t = dde.grad.jacobian(y, x, i=1)

    return [
        dr_t - 1 / ub * rb * (2.0 * ub * r - 0.04 * ub * r * ub * p),
        dp_t - 1 / ub * rb * (0.02 * r * ub * p * ub - 1.06 * p * ub),
    ]

geom = dde.geometry.TimeDomain(0, 1.0)
data = dde.data.PDE(geom, ode_system, [], 3000, 2, num_test=3000)

layer_size = [1] + [64] * 6 + [2]
activation = "tanh"
initializer = "Glorot normal"
net = dde.nn.FNN(layer_size, activation, initializer)


def input_transform(t):
    return tf.concat(
        (
            t,
            tf.sin(t),
            tf.sin(2 * t),
            tf.sin(3 * t),
            tf.sin(4 * t),
            tf.sin(5 * t),
            tf.sin(6 * t),
        ),
        axis=1,
    )


# hard constraints: x(0) = 100, y(0) = 15

def output_transform(t, y):
    y1 = y[:, 0:1]
    y2 = y[:, 1:2]
    return tf.concat([y1 * tf.tanh(t) + 100 / ub, y2 * tf.tanh(t) + 15 / ub], axis=1)

net.apply_feature_transform(input_transform)
net.apply_output_transform(output_transform)
model = dde.Model(data, net)

model.compile("adam", lr=0.001)
losshistory, train_state = model.train(iterations=50000)
model.compile("L-BFGS")
losshistory, train_state = model.train()
dde.saveplot(losshistory, train_state, issave=True, isplot=True)

plt.xlabel("t")
plt.ylabel("population")

t = np.linspace(0, 1, 100)
x_true, y_true = gen_truedata()
plt.plot(t, x_true, color="black", label="x_true")
plt.plot(t, y_true, color="blue", label="y_true")

t = t.reshape(100, 1)
sol_pred = model.predict(t)
x_pred = sol_pred[:, 0:1]
y_pred = sol_pred[:, 1:2]

plt.plot(t, x_pred, color="red", linestyle="dashed", label="x_pred")
plt.plot(t, y_pred, color="orange", linestyle="dashed", label="y_pred")
plt.legend()
plt.show()

# %% [markdown]
# ### Data-driven discovery

# %% [markdown]
# **Problem:** *What are the parameters $\lambda$ that best describe the observed data?*
#
# Again, PINNs approximate the solution $u(x)$ using a neural network $\hat{u}(x; \boldsymbol{\theta})$, where $\boldsymbol{\theta}$ represents the network parameters.

# %% [markdown]
# #### Diffusion Equation

# %% [markdown]
# **Hands-on**
#
# What happens if we change the number of training points inside the domain? What about in the inital and boundary conditions?

# %%
import deepxde as dde
import numpy as np

import torch



C = dde.Variable(2.0)


def pde(x, y):
    dy_t = dde.grad.jacobian(y, x, i=0, j=1)
    dy_xx = dde.grad.hessian(y, x, i=0, j=0)
    
    return (
         dy_t
         - C * dy_xx
         + torch.exp(-x[:, 1:])
         * (torch.sin(np.pi * x[:, 0:1]) - np.pi ** 2 * torch.sin(np.pi * x[:, 0:1]))
     )


def func(x):
    return np.sin(np.pi * x[:, 0:1]) * np.exp(-x[:, 1:])


geom = dde.geometry.Interval(-1, 1)
timedomain = dde.geometry.TimeDomain(0, 1)
geomtime = dde.geometry.GeometryXTime(geom, timedomain)

bc = dde.icbc.DirichletBC(geomtime, func, lambda _, on_boundary: on_boundary)
ic = dde.icbc.IC(geomtime, func, lambda _, on_initial: on_initial)

observe_x = np.vstack((np.linspace(-1, 1, num=10), np.full((10), 1))).T
observe_y = dde.icbc.PointSetBC(observe_x, func(observe_x), component=0)

data = dde.data.TimePDE(
    geomtime,
    pde,
    [bc, ic, observe_y],
    num_domain=40,
    num_boundary=20,
    num_initial=10,
    anchors=observe_x,
    solution=func,
    num_test=10000,
)

layer_size = [2] + [32] * 3 + [1]
activation = "tanh"
initializer = "Glorot uniform"
net = dde.nn.FNN(layer_size, activation, initializer)

model = dde.Model(data, net)

model.compile(
    "adam", lr=0.001, metrics=["l2 relative error"], external_trainable_variables=C
)
variable = dde.callbacks.VariableValue(C, period=1000)
losshistory, train_state = model.train(iterations=50000, callbacks=[variable])

dde.saveplot(losshistory, train_state, issave=True, isplot=True)
# Out:
# Warning: 10000 points required, but 10082 points sampled.
# Compiling model...
# 'compile' took 0.000105 s
#
# Training model...
#
# Step      Train loss                                  Test loss                                   Test metric
# 0         [1.31e+01, 7.06e-02, 3.57e-01, 6.22e-02]    [1.53e+01, 7.06e-02, 3.57e-01, 6.22e-02]    [8.01e-01]
# 0 [2.00e+00]
# 1000      [5.53e-03, 1.25e-02, 3.58e-02, 1.25e-02]    [7.23e-03, 1.25e-02, 3.58e-02, 1.25e-02]    [4.18e-01]
# 1000 [1.94e+00]
# 2000      [1.61e-03, 4.27e-03, 1.03e-02, 7.57e-03]    [1.94e-03, 4.27e-03, 1.03e-02, 7.57e-03]    [3.95e-01]
# 2000 [1.69e+00]
# 3000      [6.49e-04, 1.13e-03, 8.00e-04, 4.34e-03]    [5.58e-03, 1.13e-03, 8.00e-04, 4.34e-03]    [2.88e-01]
# 3000 [1.44e+00]
# 4000      [2.60e-04, 4.45e-04, 1.62e-05, 1.77e-03]    [2.14e-03, 4.45e-04, 1.62e-05, 1.77e-03]    [1.76e-01]
# 4000 [1.24e+00]
# 5000      [3.33e-04, 1.26e-04, 1.39e-05, 2.98e-04]    [8.14e-04, 1.26e-04, 1.39e-05, 2.98e-04]    [7.05e-02]
# 5000 [1.09e+00]
# 6000      [1.28e-04, 4.90e-05, 6.69e-06, 3.20e-05]    [3.93e-04, 4.90e-05, 6.69e-06, 3.20e-05]    [2.34e-02]
# 6000 [1.03e+00]
# 7000      [1.00e-04, 2.44e-05, 3.43e-06, 8.11e-06]    [3.22e-04, 2.44e-05, 3.43e-06, 8.11e-06]    [1.19e-02]
# 7000 [1.01e+00]
# 8000      [1.58e-04, 1.45e-05, 1.35e-06, 9.55e-06]    [3.39e-04, 1.45e-05, 1.35e-06, 9.55e-06]    [8.97e-03]
# 8000 [1.01e+00]
# 9000      [1.90e-03, 1.23e-04, 1.62e-05, 7.54e-05]    [1.74e-03, 1.23e-04, 1.62e-05, 7.54e-05]    [1.76e-02]
# 9000 [1.01e+00]
# 10000     [2.95e-05, 7.18e-06, 1.43e-06, 8.85e-07]    [2.30e-04, 7.18e-06, 1.43e-06, 8.85e-07]    [3.76e-03]
# 10000 [1.00e+00]
# 11000     [5.10e-04, 3.41e-05, 6.87e-06, 1.60e-05]    [5.65e-04, 3.41e-05, 6.87e-06, 1.60e-05]    [7.64e-03]
# 11000 [1.00e+00]
# 12000     [2.22e-05, 4.14e-06, 9.00e-07, 1.01e-06]    [1.94e-04, 4.14e-06, 9.00e-07, 1.01e-06]    [3.05e-03]
# 12000 [1.00e+00]
# 13000     [1.98e-04, 9.90e-06, 1.37e-06, 4.75e-06]    [2.88e-04, 9.90e-06, 1.37e-06, 4.75e-06]    [4.22e-03]
# 13000 [1.00e+00]
# 14000     [2.95e-05, 3.71e-06, 1.06e-06, 1.19e-06]    [2.08e-04, 3.71e-06, 1.06e-06, 1.19e-06]    [2.52e-03]
# 14000 [1.00e+00]
# 15000     [1.70e-05, 2.55e-06, 6.23e-07, 7.62e-07]    [1.66e-04, 2.55e-06, 6.23e-07, 7.62e-07]    [2.21e-03]
# 15000 [1.00e+00]
# 16000     [2.03e-05, 2.58e-06, 5.56e-07, 8.57e-07]    [1.60e-04, 2.58e-06, 5.56e-07, 8.57e-07]    [2.52e-03]
# 16000 [1.00e+00]
# 17000     [9.56e-05, 7.66e-06, 1.65e-06, 6.77e-06]    [2.17e-04, 7.66e-06, 1.65e-06, 6.77e-06]    [5.39e-03]
# 17000 [1.00e+00]
# 18000     [4.49e-04, 2.52e-05, 4.27e-06, 1.24e-05]    [6.14e-04, 2.52e-05, 4.27e-06, 1.24e-05]    [6.31e-03]
# 18000 [1.00e+00]
# 19000     [5.38e-04, 2.47e-05, 4.85e-06, 1.08e-05]    [5.19e-04, 2.47e-05, 4.85e-06, 1.08e-05]    [6.56e-03]
# 19000 [1.00e+00]
# 20000     [7.55e-05, 1.35e-05, 2.46e-06, 2.16e-05]    [2.05e-04, 1.35e-05, 2.46e-06, 2.16e-05]    [8.32e-03]
# 20000 [1.00e+00]
# 21000     [2.18e-04, 1.19e-05, 3.01e-06, 4.57e-06]    [3.82e-04, 1.19e-05, 3.01e-06, 4.57e-06]    [4.38e-03]
# 21000 [1.00e+00]
# 22000     [1.61e-05, 1.55e-06, 4.24e-07, 1.64e-06]    [1.54e-04, 1.55e-06, 4.24e-07, 1.64e-06]    [2.17e-03]
# 22000 [9.99e-01]
# 23000     [7.59e-05, 4.60e-06, 1.29e-06, 4.32e-07]    [1.88e-04, 4.60e-06, 1.29e-06, 4.31e-07]    [2.84e-03]
# 23000 [1.00e+00]
# 24000     [2.12e-05, 1.61e-06, 3.28e-07, 9.01e-07]    [1.50e-04, 1.61e-06, 3.28e-07, 9.01e-07]    [2.09e-03]
# 24000 [9.99e-01]
# 25000     [2.13e-04, 1.28e-05, 1.93e-06, 5.28e-06]    [3.63e-04, 1.28e-05, 1.93e-06, 5.28e-06]    [4.17e-03]
# 25000 [9.99e-01]
# 26000     [1.41e-05, 8.83e-07, 3.35e-07, 1.02e-06]    [1.51e-04, 8.83e-07, 3.35e-07, 1.02e-06]    [1.89e-03]
# 26000 [9.99e-01]
# 27000     [1.26e-04, 5.35e-06, 2.27e-06, 1.84e-06]    [2.76e-04, 5.35e-06, 2.27e-06, 1.84e-06]    [3.34e-03]
# 27000 [9.99e-01]
# 28000     [2.61e-05, 1.43e-06, 2.16e-07, 7.74e-07]    [1.63e-04, 1.43e-06, 2.16e-07, 7.74e-07]    [1.59e-03]
# 28000 [9.99e-01]
# 29000     [1.84e-05, 1.13e-06, 2.43e-07, 5.89e-07]    [1.55e-04, 1.13e-06, 2.43e-07, 5.89e-07]    [1.71e-03]
# 29000 [9.99e-01]
# 30000     [6.10e-06, 7.27e-07, 3.06e-07, 4.12e-07]    [1.57e-04, 7.27e-07, 3.06e-07, 4.12e-07]    [1.88e-03]
# 30000 [9.99e-01]
# 31000     [6.23e-06, 1.01e-06, 1.84e-07, 1.14e-06]    [1.59e-04, 1.01e-06, 1.85e-07, 1.14e-06]    [2.29e-03]
# 31000 [9.99e-01]
# 32000     [4.54e-05, 2.74e-06, 2.34e-07, 1.18e-06]    [2.03e-04, 2.74e-06, 2.34e-07, 1.18e-06]    [2.05e-03]
# 32000 [9.99e-01]
# 33000     [1.51e-03, 6.01e-05, 2.02e-05, 1.62e-05]    [1.31e-03, 6.01e-05, 2.02e-05, 1.62e-05]    [9.55e-03]
# 33000 [9.99e-01]
# 34000     [5.88e-05, 2.40e-06, 1.15e-06, 2.98e-07]    [2.07e-04, 2.40e-06, 1.15e-06, 2.99e-07]    [2.17e-03]
# 34000 [9.99e-01]
# 35000     [9.52e-06, 9.51e-07, 1.92e-07, 6.93e-07]    [1.60e-04, 9.51e-07, 1.92e-07, 6.93e-07]    [1.93e-03]
# 35000 [9.99e-01]
# 36000     [6.29e-06, 1.16e-06, 3.76e-07, 1.77e-06]    [1.62e-04, 1.17e-06, 3.76e-07, 1.77e-06]    [2.35e-03]
# 36000 [9.99e-01]
# 37000     [7.74e-05, 5.47e-06, 7.44e-07, 3.59e-06]    [2.45e-04, 5.47e-06, 7.44e-07, 3.59e-06]    [3.42e-03]
# 37000 [9.99e-01]
# 38000     [2.20e-06, 3.93e-07, 2.02e-07, 2.55e-07]    [1.64e-04, 3.93e-07, 2.02e-07, 2.55e-07]    [1.53e-03]
# 38000 [9.99e-01]
# 39000     [9.35e-06, 9.48e-07, 3.16e-07, 5.76e-07]    [1.77e-04, 9.48e-07, 3.16e-07, 5.76e-07]    [1.71e-03]
# 39000 [9.99e-01]
# 40000     [8.03e-06, 6.73e-07, 9.67e-08, 3.99e-07]    [1.67e-04, 6.73e-07, 9.66e-08, 3.99e-07]    [1.39e-03]
# 40000 [9.99e-01]
# 41000     [9.61e-05, 4.81e-06, 1.41e-06, 1.13e-06]    [2.30e-04, 4.81e-06, 1.41e-06, 1.13e-06]    [3.09e-03]
# 41000 [9.99e-01]
# 42000     [2.64e-05, 1.58e-06, 1.88e-07, 7.61e-07]    [1.72e-04, 1.58e-06, 1.88e-07, 7.61e-07]    [1.91e-03]
# 42000 [9.99e-01]
# 43000     [2.25e-06, 3.85e-07, 1.38e-07, 2.57e-07]    [1.65e-04, 3.85e-07, 1.38e-07, 2.57e-07]    [1.43e-03]
# 43000 [9.99e-01]
# 44000     [1.87e-06, 3.59e-07, 1.36e-07, 2.45e-07]    [1.67e-04, 3.59e-07, 1.36e-07, 2.45e-07]    [1.40e-03]
# 44000 [9.99e-01]
# 45000     [1.05e-03, 3.06e-05, 1.28e-05, 9.74e-06]    [1.04e-03, 3.06e-05, 1.28e-05, 9.74e-06]    [7.59e-03]
# 45000 [9.99e-01]
# 46000     [5.53e-05, 6.16e-07, 6.81e-07, 9.92e-07]    [2.02e-04, 6.16e-07, 6.81e-07, 9.92e-07]    [2.01e-03]
# 46000 [9.99e-01]
# 47000     [6.62e-05, 3.13e-06, 3.08e-07, 1.08e-06]    [2.40e-04, 3.13e-06, 3.08e-07, 1.08e-06]    [2.30e-03]
# 47000 [9.99e-01]
# 48000     [7.12e-05, 6.23e-06, 5.83e-07, 5.54e-06]    [2.00e-04, 6.23e-06, 5.83e-07, 5.54e-06]    [4.37e-03]
# 48000 [9.99e-01]
# 49000     [2.83e-06, 3.88e-07, 1.06e-07, 2.40e-07]    [1.65e-04, 3.88e-07, 1.06e-07, 2.40e-07]    [1.39e-03]
# 49000 [9.99e-01]
# 50000     [1.00e-04, 1.88e-06, 1.79e-06, 1.29e-06]    [2.71e-04, 1.88e-06, 1.79e-06, 1.29e-06]    [3.06e-03]
# 50000 [9.99e-01]
#
# Best model at step 44000:
#   train loss: 2.61e-06
#   test loss: 1.67e-04
#   test metric: [1.40e-03]
#
# 'train' took 37.689249 s
#
# Saving loss history to /Users/ceciliacoelho/Downloads/jupyterNotebook/loss.dat ...
# Saving training data to /Users/ceciliacoelho/Downloads/jupyterNotebook/train.dat ...
# Saving test data to /Users/ceciliacoelho/Downloads/jupyterNotebook/test.dat ...

# %% [markdown]
# #### Lorenz System

# %% [markdown]
# **Hands-on**
#
# Use PINNs to discover $\sigma, \rho, \beta$ for the following Lorenz system:
#                 $$\begin{align*}
#                     \dfrac{dx}{dt}=\sigma(y-x), \quad \dfrac{dy}{dt}=x(\rho-z)-y, \quad \dfrac{dz}{dt}=xy-\beta z, \quad t\in[0,3]\\
#                     x(0)=-8, \quad y(0)=7, \quad z(0) = 27.
#                 \end{align*}$$

# %%
"""Backend supported: tensorflow.compat.v1, tensorflow, pytorch, jax"""
import deepxde as dde
import numpy as np


def gen_traindata():
    data = np.load("Lorenz.npz")
    return data["t"], data["y"]


C1 = dde.Variable(1.0)
C2 = dde.Variable(1.0)
C3 = dde.Variable(1.0)

# Most backends
def Lorenz_system(x, y):
    """Lorenz system.
    dy1/dx = 10 * (y2 - y1)
    dy2/dx = y1 * (15 - y3) - y2
    dy3/dx = y1 * y2 - 8/3 * y3
    """
    y1, y2, y3 = y[:, 0:1], y[:, 1:2], y[:, 2:]
    dy1_x = dde.grad.jacobian(y, x, i=0)
    dy2_x = dde.grad.jacobian(y, x, i=1)
    dy3_x = dde.grad.jacobian(y, x, i=2)
    return [
        dy1_x - C1 * (y2 - y1),
        dy2_x - y1 * (C2 - y3) + y2,
        dy3_x - y1 * y2 + C3 * y3,
    ]


def boundary(_, on_initial):
    return on_initial


geom = dde.geometry.TimeDomain(0, 3)

# Initial conditions
ic1 = dde.icbc.IC(geom, lambda X: -8, boundary, component=0)
ic2 = dde.icbc.IC(geom, lambda X: 7, boundary, component=1)
ic3 = dde.icbc.IC(geom, lambda X: 27, boundary, component=2)

# Get the train data
observe_t, ob_y = gen_traindata()
observe_y0 = dde.icbc.PointSetBC(observe_t, ob_y[:, 0:1], component=0)
observe_y1 = dde.icbc.PointSetBC(observe_t, ob_y[:, 1:2], component=1)
observe_y2 = dde.icbc.PointSetBC(observe_t, ob_y[:, 2:3], component=2)

data = dde.data.PDE(
    geom,
    Lorenz_system,
    [ic1, ic2, ic3, observe_y0, observe_y1, observe_y2],
    num_domain=400,
    num_boundary=2,
    anchors=observe_t,
)

net = dde.nn.FNN([1] + [40] * 3 + [3], "tanh", "Glorot uniform")
model = dde.Model(data, net)

external_trainable_variables = [C1, C2, C3]
variable = dde.callbacks.VariableValue(
    external_trainable_variables, period=600, filename="variables.dat"
)

# train adam
model.compile(
    "adam", lr=0.001, external_trainable_variables=external_trainable_variables
)
losshistory, train_state = model.train(iterations=20000, callbacks=[variable])

# train 2nd time with LBFGS
model.compile("L-BFGS", external_trainable_variables=external_trainable_variables)
losshistory, train_state = model.train(callbacks=[variable])

dde.saveplot(losshistory, train_state, issave=True, isplot=True)
# Out:
# Compiling model...
# 'compile' took 0.000196 s
#
# Training model...
#
# Step      Train loss                                                                                    Test loss                                                                                     Test metric
# 0         [5.08e-01, 4.98e-01, 2.40e-01, 6.40e+01, 4.90e+01, 7.29e+02, 3.88e+01, 3.93e+01, 2.65e+02]    [5.08e-01, 4.98e-01, 2.40e-01, 6.40e+01, 4.90e+01, 7.29e+02, 3.88e+01, 3.93e+01, 2.65e+02]    []
# 1000      [6.68e+00, 2.52e+00, 2.61e+00, 2.89e+01, 2.01e-02, 1.70e+00, 3.29e+01, 7.87e+00, 9.82e+00]    [6.68e+00, 2.52e+00, 2.61e+00, 2.89e+01, 2.01e-02, 1.70e+00, 3.29e+01, 7.87e+00, 9.82e+00]    []
# 2000      [9.31e+00, 1.93e+00, 1.19e+00, 1.67e+01, 3.51e-01, 1.61e+00, 3.29e+01, 1.56e+01, 4.27e+00]    [9.31e+00, 1.93e+00, 1.19e+00, 1.67e+01, 3.51e-01, 1.61e+00, 3.29e+01, 1.56e+01, 4.27e+00]    []
# 3000      [8.48e+00, 1.98e+00, 9.44e-01, 1.32e+01, 3.87e-01, 1.47e+00, 3.30e+01, 1.92e+01, 2.47e+00]    [8.48e+00, 1.98e+00, 9.44e-01, 1.32e+01, 3.87e-01, 1.47e+00, 3.30e+01, 1.92e+01, 2.47e+00]    []
# 4000      [8.16e+00, 2.10e+00, 6.96e-01, 1.11e+01, 3.89e-01, 1.34e+00, 3.27e+01, 1.99e+01, 2.14e+00]    [8.16e+00, 2.10e+00, 6.96e-01, 1.11e+01, 3.89e-01, 1.34e+00, 3.27e+01, 1.99e+01, 2.14e+00]    []
# 5000      [7.97e+00, 2.23e+00, 5.50e-01, 9.55e+00, 3.75e-01, 1.25e+00, 3.24e+01, 2.01e+01, 1.90e+00]    [7.97e+00, 2.23e+00, 5.50e-01, 9.55e+00, 3.75e-01, 1.25e+00, 3.24e+01, 2.01e+01, 1.90e+00]    []
# 6000      [7.59e+00, 2.44e+00, 4.44e-01, 8.21e+00, 3.58e-01, 1.13e+00, 3.21e+01, 2.02e+01, 1.74e+00]    [7.59e+00, 2.44e+00, 4.44e-01, 8.21e+00, 3.58e-01, 1.13e+00, 3.21e+01, 2.02e+01, 1.74e+00]    []
# 7000      [6.99e+00, 2.88e+00, 3.28e-01, 6.88e+00, 3.37e-01, 9.85e-01, 3.13e+01, 2.02e+01, 1.75e+00]    [6.99e+00, 2.88e+00, 3.28e-01, 6.88e+00, 3.37e-01, 9.85e-01, 3.13e+01, 2.02e+01, 1.75e+00]    []
# 8000      [2.15e+00, 3.06e+00, 8.07e-01, 3.80e+00, 4.49e-01, 3.93e-01, 1.29e+01, 1.28e+01, 1.37e+01]    [2.15e+00, 3.06e+00, 8.07e-01, 3.80e+00, 4.49e-01, 3.93e-01, 1.29e+01, 1.28e+01, 1.37e+01]    []
# 9000      [6.30e-01, 1.39e+00, 4.42e-01, 1.48e+00, 2.18e-01, 1.76e-02, 4.32e+00, 4.13e+00, 1.10e+01]    [6.30e-01, 1.39e+00, 4.42e-01, 1.48e+00, 2.18e-01, 1.76e-02, 4.32e+00, 4.13e+00, 1.10e+01]    []
# 10000     [3.15e-01, 6.96e-01, 3.09e-01, 7.53e-01, 7.90e-02, 2.95e-03, 2.09e+00, 2.03e+00, 7.31e+00]    [3.15e-01, 6.96e-01, 3.09e-01, 7.53e-01, 7.90e-02, 2.95e-03, 2.09e+00, 2.03e+00, 7.31e+00]    []
# 11000     [1.94e-01, 4.65e-01, 2.35e-01, 4.41e-01, 3.15e-02, 2.19e-02, 1.23e+00, 1.19e+00, 4.48e+00]    [1.94e-01, 4.65e-01, 2.35e-01, 4.41e-01, 3.15e-02, 2.19e-02, 1.23e+00, 1.19e+00, 4.48e+00]    []
# 12000     [1.23e-01, 2.94e-01, 2.00e-01, 2.40e-01, 1.23e-02, 2.39e-02, 7.85e-01, 7.57e-01, 2.48e+00]    [1.23e-01, 2.94e-01, 2.00e-01, 2.40e-01, 1.23e-02, 2.39e-02, 7.85e-01, 7.57e-01, 2.48e+00]    []
# 13000     [7.98e-02, 1.91e-01, 1.37e-01, 1.36e-01, 5.26e-03, 2.12e-02, 4.84e-01, 4.39e-01, 1.15e+00]    [7.98e-02, 1.91e-01, 1.37e-01, 1.36e-01, 5.26e-03, 2.12e-02, 4.84e-01, 4.39e-01, 1.15e+00]    []
# 14000     [4.82e-02, 1.32e-01, 8.28e-02, 7.04e-02, 1.49e-03, 1.60e-02, 2.68e-01, 2.27e-01, 4.48e-01]    [4.82e-02, 1.32e-01, 8.28e-02, 7.04e-02, 1.49e-03, 1.60e-02, 2.68e-01, 2.27e-01, 4.48e-01]    []
# 15000     [2.88e-02, 8.28e-02, 4.82e-02, 3.23e-02, 5.94e-04, 8.85e-03, 1.43e-01, 1.18e-01, 1.79e-01]    [2.88e-02, 8.28e-02, 4.82e-02, 3.23e-02, 5.94e-04, 8.85e-03, 1.43e-01, 1.18e-01, 1.79e-01]    []
# 16000     [1.58e-02, 5.76e-02, 2.85e-02, 1.21e-02, 3.25e-04, 4.64e-03, 7.01e-02, 5.82e-02, 7.86e-02]    [1.58e-02, 5.76e-02, 2.85e-02, 1.21e-02, 3.25e-04, 4.64e-03, 7.01e-02, 5.82e-02, 7.86e-02]    []
# 17000     [1.12e-02, 4.52e-02, 1.81e-02, 5.60e-03, 7.01e-05, 5.68e-04, 3.04e-02, 2.66e-02, 3.69e-02]    [1.12e-02, 4.52e-02, 1.81e-02, 5.60e-03, 7.01e-05, 5.68e-04, 3.04e-02, 2.66e-02, 3.69e-02]    []
# 18000     [5.58e-02, 5.89e-02, 4.14e-02, 3.53e-03, 1.94e-04, 4.03e-04, 1.28e-02, 1.31e-02, 1.92e-02]    [5.58e-02, 5.89e-02, 4.14e-02, 3.53e-03, 1.94e-04, 4.03e-04, 1.28e-02, 1.31e-02, 1.92e-02]    []
# 19000     [1.36e-02, 4.01e-02, 1.88e-02, 4.05e-04, 1.10e-04, 4.89e-06, 5.77e-03, 5.84e-03, 9.29e-03]    [1.36e-02, 4.01e-02, 1.88e-02, 4.05e-04, 1.10e-04, 4.89e-06, 5.77e-03, 5.84e-03, 9.29e-03]    []
# 20000     [1.77e-02, 3.51e-02, 1.51e-02, 2.24e-04, 5.93e-06, 5.75e-05, 3.23e-03, 3.75e-03, 6.24e-03]    [1.77e-02, 3.51e-02, 1.51e-02, 2.24e-04, 5.93e-06, 5.75e-05, 3.23e-03, 3.75e-03, 6.24e-03]    []
#
# Best model at step 20000:
#   train loss: 8.13e-02
#   test loss: 8.13e-02
#   test metric: []
#
# 'train' took 24.310269 s
#
# Compiling model...
# 'compile' took 0.000168 s
#
# Training model...
#
# Step      Train loss                                                                                    Test loss                                                                                     Test metric
# 20000     [1.77e-02, 3.51e-02, 1.51e-02, 2.24e-04, 5.93e-06, 5.75e-05, 3.23e-03, 3.75e-03, 6.24e-03]    [1.77e-02, 3.51e-02, 1.51e-02, 2.24e-04, 5.93e-06, 5.75e-05, 3.23e-03, 3.75e-03, 6.24e-03]    []
# 21000     [7.77e-04, 1.36e-03, 1.87e-03, 1.45e-06, 4.06e-06, 2.46e-07, 2.60e-05, 3.27e-05, 6.67e-05]    [7.77e-04, 1.36e-03, 1.87e-03, 1.45e-06, 4.06e-06, 2.46e-07, 2.60e-05, 3.27e-05, 6.67e-05]    []
# 22000     [2.30e-04, 3.90e-04, 4.17e-04, 8.60e-08, 1.25e-06, 9.78e-08, 8.23e-06, 4.59e-06, 1.03e-05]    [2.30e-04, 3.90e-04, 4.17e-04, 8.60e-08, 1.25e-06, 9.78e-08, 8.23e-06, 4.59e-06, 1.03e-05]    []
# 22194     [1.96e-04, 3.92e-04, 3.03e-04, 1.99e-08, 4.53e-07, 1.22e-08, 7.85e-06, 5.01e-06, 8.47e-06]    [1.96e-04, 3.92e-04, 3.03e-04, 1.99e-08, 4.53e-07, 1.22e-08, 7.85e-06, 5.01e-06, 8.47e-06]    []
#
# Best model at step 22194:
#   train loss: 9.13e-04
#   test loss: 9.13e-04
#   test metric: []
#
# 'train' took 4.219229 s
#
# Saving loss history to /Users/ceciliacoelho/Downloads/jupyterNotebook/loss.dat ...
# Saving training data to /Users/ceciliacoelho/Downloads/jupyterNotebook/train.dat ...
# Saving test data to /Users/ceciliacoelho/Downloads/jupyterNotebook/test.dat ...

# %% [markdown]
# # --------------------------------------------------------

# %% [markdown]
# ## Neural ODEs

# %%
pip install torchdiffeq
# Out:
# Requirement already satisfied: torchdiffeq in /opt/homebrew/lib/python3.13/site-packages (0.2.5)
# Requirement already satisfied: torch>=1.5.0 in /opt/homebrew/lib/python3.13/site-packages (from torchdiffeq) (2.6.0)
# Requirement already satisfied: scipy>=1.4.0 in /opt/homebrew/lib/python3.13/site-packages (from torchdiffeq) (1.15.2)
# Requirement already satisfied: numpy<2.5,>=1.23.5 in /opt/homebrew/lib/python3.13/site-packages (from scipy>=1.4.0->torchdiffeq) (2.2.3)
# Requirement already satisfied: filelock in /opt/homebrew/lib/python3.13/site-packages (from torch>=1.5.0->torchdiffeq) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/homebrew/Cellar/jupyterlab/4.4.3_1/libexec/lib/python3.13/site-packages (from torch>=1.5.0->torchdiffeq) (4.14.0)
# Requirement already satisfied: networkx in /opt/homebrew/lib/python3.13/site-packages (from torch>=1.5.0->torchdiffeq) (3.4.2)
# Requirement already satisfied: jinja2 in /opt/homebrew/Cellar/jupyterlab/4.4.3_1/libexec/lib/python3.13/site-packages (from torch>=1.5.0->torchdiffeq) (3.1.6)
# Requirement already satisfied: fsspec in /opt/homebrew/lib/python3.13/site-packages (from torch>=1.5.0->torchdiffeq) (2025.2.0)
# Requirement already satisfied: setuptools in /opt/homebrew/Cellar/jupyterlab/4.4.3_1/libexec/lib/python3.13/site-packages (from torch>=1.5.0->torchdiffeq) (80.9.0)
# Requirement already satisfied: sympy==1.13.1 in /opt/homebrew/lib/python3.13/site-packages (from torch>=1.5.0->torchdiffeq) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/homebrew/lib/python3.13/site-packages (from sympy==1.13.1->torch>=1.5.0->torchdiffeq) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/Cellar/jupyterlab/4.4.3_1/libexec/lib/python3.13/site-packages (from jinja2->torch>=1.5.0->torchdiffeq) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

import torch
import torch.nn as nn
import torch.optim as optim

from torchdiffeq import odeint

# %% [markdown]
# ### Learning a population dynamics

# %%
#########################################Building the synthetic dataset
device = torch.device('cuda:' + str(args.gpu) if torch.cuda.is_available() else 'cpu')

true_y0 = torch.tensor([2.518629]).to(device)

t = torch.linspace(0., 1, 500).to(device)
t_test = torch.linspace(0., 1, 700).to(device)



class Lambda(nn.Module):

    def forward(self, t, y):
        return torch.mul(torch.mul(0.026, y), torch.sub(1, torch.div(y,12)))


with torch.no_grad():
    true_y = odeint(Lambda(), true_y0, t, method='dopri5')
    test_y = odeint(Lambda(), true_y0, t_test, method='dopri5')
########################################

class ODEFunc(nn.Module):

    def __init__(self):
        super(ODEFunc, self).__init__()

        self.net = nn.Sequential(
            nn.Linear(1, 50),
            nn.Tanh(),
            nn.Linear(50,50),
            nn.ELU(),
            nn.Linear(50, 1),
        )

        for m in self.net.modules():
            if isinstance(m, nn.Linear):
                nn.init.normal_(m.weight, mean=0, std=0.1)
                nn.init.constant_(m.bias, val=0)

    def forward(self, t, y):
        return self.net(y)

if __name__ == '__main__':

    func = ODEFunc().to(device)

    optimizer = optim.Adam(func.parameters(), lr=1e-5)

    for itr in range(1, 1000):
        pred_y = odeint(func, true_y0, t, method='rk4').to(device)
        loss = nn.MSELoss()(pred_y, true_y)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()


        if itr % 1 == 0:
            with torch.no_grad():
                print('Iter {:04d} | MSE Loss {:.6f}'.format(itr, loss.item()))

                if itr == 2000:
                    pred_y_test = odeint(func, true_y0, t_test)
                    mse_t = nn.MSELoss()(pred_y_test, test_y)
                    print('MSE Loss {:.6f}'.format(mse_t.item()))
                    plt.plot(t_test.detach().cpu().numpy(), test_y.detach().cpu().numpy(), linestyle='dashed', label='real')
                    plt.plot(t_test.detach().cpu().numpy(), pred_y_test.detach().cpu().numpy(), label='predicted')
                    plt.xlabel("Time")
                    plt.ylabel("Population")
                    plt.legend()
                    plt.show()
# Out:
# Iter 0001 | MSE Loss 0.000923
# Iter 0002 | MSE Loss 0.000904
# Iter 0003 | MSE Loss 0.000886
# Iter 0004 | MSE Loss 0.000868
# Iter 0005 | MSE Loss 0.000850
# Iter 0006 | MSE Loss 0.000832
# Iter 0007 | MSE Loss 0.000815
# Iter 0008 | MSE Loss 0.000798
# Iter 0009 | MSE Loss 0.000780
# Iter 0010 | MSE Loss 0.000764
# Iter 0011 | MSE Loss 0.000747
# Iter 0012 | MSE Loss 0.000731
# Iter 0013 | MSE Loss 0.000714
# Iter 0014 | MSE Loss 0.000698
# Iter 0015 | MSE Loss 0.000683
# Iter 0016 | MSE Loss 0.000667
# Iter 0017 | MSE Loss 0.000652
# Iter 0018 | MSE Loss 0.000637
# Iter 0019 | MSE Loss 0.000622
# Iter 0020 | MSE Loss 0.000607
# Iter 0021 | MSE Loss 0.000593
# Iter 0022 | MSE Loss 0.000579
# Iter 0023 | MSE Loss 0.000565
# Iter 0024 | MSE Loss 0.000551
# Iter 0025 | MSE Loss 0.000538
# Iter 0026 | MSE Loss 0.000525
# Iter 0027 | MSE Loss 0.000512
# Iter 0028 | MSE Loss 0.000499
# Iter 0029 | MSE Loss 0.000486
# Iter 0030 | MSE Loss 0.000474
# Iter 0031 | MSE Loss 0.000462
# Iter 0032 | MSE Loss 0.000450
# Iter 0033 | MSE Loss 0.000438
# Iter 0034 | MSE Loss 0.000427
# Iter 0035 | MSE Loss 0.000416
# Iter 0036 | MSE Loss 0.000405
# Iter 0037 | MSE Loss 0.000394
# Iter 0038 | MSE Loss 0.000383
# Iter 0039 | MSE Loss 0.000373
# Iter 0040 | MSE Loss 0.000363
# Iter 0041 | MSE Loss 0.000353
# Iter 0042 | MSE Loss 0.000343
# Iter 0043 | MSE Loss 0.000334
# Iter 0044 | MSE Loss 0.000325
# Iter 0045 | MSE Loss 0.000315
# Iter 0046 | MSE Loss 0.000307
# Iter 0047 | MSE Loss 0.000298
# Iter 0048 | MSE Loss 0.000289
# Iter 0049 | MSE Loss 0.000281
# Iter 0050 | MSE Loss 0.000273
# Iter 0051 | MSE Loss 0.000265
# Iter 0052 | MSE Loss 0.000257
# Iter 0053 | MSE Loss 0.000250
# Iter 0054 | MSE Loss 0.000242
# Iter 0055 | MSE Loss 0.000235
# Iter 0056 | MSE Loss 0.000228
# Iter 0057 | MSE Loss 0.000221
# Iter 0058 | MSE Loss 0.000214
# Iter 0059 | MSE Loss 0.000208
# Iter 0060 | MSE Loss 0.000201
# Iter 0061 | MSE Loss 0.000195
# Iter 0062 | MSE Loss 0.000189
# Iter 0063 | MSE Loss 0.000183
# Iter 0064 | MSE Loss 0.000177
# Iter 0065 | MSE Loss 0.000172
# Iter 0066 | MSE Loss 0.000166
# Iter 0067 | MSE Loss 0.000161
# Iter 0068 | MSE Loss 0.000156
# Iter 0069 | MSE Loss 0.000151
# Iter 0070 | MSE Loss 0.000146
# Iter 0071 | MSE Loss 0.000141
# Iter 0072 | MSE Loss 0.000136
# Iter 0073 | MSE Loss 0.000132
# Iter 0074 | MSE Loss 0.000127
# Iter 0075 | MSE Loss 0.000123
# Iter 0076 | MSE Loss 0.000119
# Iter 0077 | MSE Loss 0.000115
# Iter 0078 | MSE Loss 0.000111
# Iter 0079 | MSE Loss 0.000107
# Iter 0080 | MSE Loss 0.000103
# Iter 0081 | MSE Loss 0.000100
# Iter 0082 | MSE Loss 0.000096
# Iter 0083 | MSE Loss 0.000093
# Iter 0084 | MSE Loss 0.000089
# Iter 0085 | MSE Loss 0.000086
# Iter 0086 | MSE Loss 0.000083
# Iter 0087 | MSE Loss 0.000080
# Iter 0088 | MSE Loss 0.000077
# Iter 0089 | MSE Loss 0.000074
# Iter 0090 | MSE Loss 0.000072
# Iter 0091 | MSE Loss 0.000069
# Iter 0092 | MSE Loss 0.000066
# Iter 0093 | MSE Loss 0.000064
# Iter 0094 | MSE Loss 0.000062
# Iter 0095 | MSE Loss 0.000059
# Iter 0096 | MSE Loss 0.000057
# Iter 0097 | MSE Loss 0.000055
# Iter 0098 | MSE Loss 0.000053
# Iter 0099 | MSE Loss 0.000051
# Iter 0100 | MSE Loss 0.000049
# Iter 0101 | MSE Loss 0.000047
# Iter 0102 | MSE Loss 0.000045
# Iter 0103 | MSE Loss 0.000043
# Iter 0104 | MSE Loss 0.000041
# Iter 0105 | MSE Loss 0.000040
# Iter 0106 | MSE Loss 0.000038
# Iter 0107 | MSE Loss 0.000037
# Iter 0108 | MSE Loss 0.000035
# Iter 0109 | MSE Loss 0.000034
# Iter 0110 | MSE Loss 0.000032
# Iter 0111 | MSE Loss 0.000031
# Iter 0112 | MSE Loss 0.000030
# Iter 0113 | MSE Loss 0.000028
# Iter 0114 | MSE Loss 0.000027
# Iter 0115 | MSE Loss 0.000026
# Iter 0116 | MSE Loss 0.000025
# Iter 0117 | MSE Loss 0.000024
# Iter 0118 | MSE Loss 0.000023
# Iter 0119 | MSE Loss 0.000022
# Iter 0120 | MSE Loss 0.000021
# Iter 0121 | MSE Loss 0.000020
# Iter 0122 | MSE Loss 0.000019
# Iter 0123 | MSE Loss 0.000018
# Iter 0124 | MSE Loss 0.000018
# Iter 0125 | MSE Loss 0.000017
# Iter 0126 | MSE Loss 0.000016
# Iter 0127 | MSE Loss 0.000015
# Iter 0128 | MSE Loss 0.000015
# Iter 0129 | MSE Loss 0.000014
# Iter 0130 | MSE Loss 0.000013
# Iter 0131 | MSE Loss 0.000013
# Iter 0132 | MSE Loss 0.000012
# Iter 0133 | MSE Loss 0.000012
# Iter 0134 | MSE Loss 0.000011
# Iter 0135 | MSE Loss 0.000010
# Iter 0136 | MSE Loss 0.000010
# Iter 0137 | MSE Loss 0.000010
# Iter 0138 | MSE Loss 0.000009
# Iter 0139 | MSE Loss 0.000009
# Iter 0140 | MSE Loss 0.000008
# Iter 0141 | MSE Loss 0.000008
# Iter 0142 | MSE Loss 0.000007
# Iter 0143 | MSE Loss 0.000007
# Iter 0144 | MSE Loss 0.000007
# Iter 0145 | MSE Loss 0.000006
# Iter 0146 | MSE Loss 0.000006
# Iter 0147 | MSE Loss 0.000006
# Iter 0148 | MSE Loss 0.000005
# Iter 0149 | MSE Loss 0.000005
# Iter 0150 | MSE Loss 0.000005
# Iter 0151 | MSE Loss 0.000005
# Iter 0152 | MSE Loss 0.000004
# Iter 0153 | MSE Loss 0.000004
# Iter 0154 | MSE Loss 0.000004
# Iter 0155 | MSE Loss 0.000004
# Iter 0156 | MSE Loss 0.000004
# Iter 0157 | MSE Loss 0.000003
# Iter 0158 | MSE Loss 0.000003
# Iter 0159 | MSE Loss 0.000003
# Iter 0160 | MSE Loss 0.000003
# Iter 0161 | MSE Loss 0.000003
# Iter 0162 | MSE Loss 0.000003
# Iter 0163 | MSE Loss 0.000002
# Iter 0164 | MSE Loss 0.000002
# Iter 0165 | MSE Loss 0.000002
# Iter 0166 | MSE Loss 0.000002
# Iter 0167 | MSE Loss 0.000002
# Iter 0168 | MSE Loss 0.000002
# Iter 0169 | MSE Loss 0.000002
# Iter 0170 | MSE Loss 0.000002
# Iter 0171 | MSE Loss 0.000002
# Iter 0172 | MSE Loss 0.000001
# Iter 0173 | MSE Loss 0.000001
# Iter 0174 | MSE Loss 0.000001
# Iter 0175 | MSE Loss 0.000001
# Iter 0176 | MSE Loss 0.000001
# Iter 0177 | MSE Loss 0.000001
# Iter 0178 | MSE Loss 0.000001
# Iter 0179 | MSE Loss 0.000001
# Iter 0180 | MSE Loss 0.000001
# Iter 0181 | MSE Loss 0.000001
# Iter 0182 | MSE Loss 0.000001
# Iter 0183 | MSE Loss 0.000001
# Iter 0184 | MSE Loss 0.000001
# Iter 0185 | MSE Loss 0.000001
# Iter 0186 | MSE Loss 0.000001
# Iter 0187 | MSE Loss 0.000001
# Iter 0188 | MSE Loss 0.000001
# Iter 0189 | MSE Loss 0.000001
# Iter 0190 | MSE Loss 0.000000
# Iter 0191 | MSE Loss 0.000000
# Iter 0192 | MSE Loss 0.000000
# Iter 0193 | MSE Loss 0.000000
# Iter 0194 | MSE Loss 0.000000
# Iter 0195 | MSE Loss 0.000000
# Iter 0196 | MSE Loss 0.000000
# Iter 0197 | MSE Loss 0.000000
# Iter 0198 | MSE Loss 0.000000
# Iter 0199 | MSE Loss 0.000000
# Iter 0200 | MSE Loss 0.000000
# Iter 0201 | MSE Loss 0.000000
# Iter 0202 | MSE Loss 0.000000
# Iter 0203 | MSE Loss 0.000000
# Iter 0204 | MSE Loss 0.000000
# Iter 0205 | MSE Loss 0.000000
# Iter 0206 | MSE Loss 0.000000
# Iter 0207 | MSE Loss 0.000000
# Iter 0208 | MSE Loss 0.000000
# Iter 0209 | MSE Loss 0.000000
# Iter 0210 | MSE Loss 0.000000
# Iter 0211 | MSE Loss 0.000000
# Iter 0212 | MSE Loss 0.000000
# Iter 0213 | MSE Loss 0.000000
# Iter 0214 | MSE Loss 0.000000
# Iter 0215 | MSE Loss 0.000000
# Iter 0216 | MSE Loss 0.000000
# Iter 0217 | MSE Loss 0.000000
# Iter 0218 | MSE Loss 0.000000
# Iter 0219 | MSE Loss 0.000000
# Iter 0220 | MSE Loss 0.000000
# Iter 0221 | MSE Loss 0.000000
# Iter 0222 | MSE Loss 0.000000
# Iter 0223 | MSE Loss 0.000000
# Iter 0224 | MSE Loss 0.000000
# Iter 0225 | MSE Loss 0.000000
# Iter 0226 | MSE Loss 0.000000
# Iter 0227 | MSE Loss 0.000000
# Iter 0228 | MSE Loss 0.000000
# Iter 0229 | MSE Loss 0.000000
# Iter 0230 | MSE Loss 0.000000
# Iter 0231 | MSE Loss 0.000000
# Iter 0232 | MSE Loss 0.000000
# Iter 0233 | MSE Loss 0.000000
# Iter 0234 | MSE Loss 0.000000
# Iter 0235 | MSE Loss 0.000000
# Iter 0236 | MSE Loss 0.000000
# Iter 0237 | MSE Loss 0.000000
# Iter 0238 | MSE Loss 0.000000
# Iter 0239 | MSE Loss 0.000000
# Iter 0240 | MSE Loss 0.000000
# Iter 0241 | MSE Loss 0.000000
# Iter 0242 | MSE Loss 0.000000
# Iter 0243 | MSE Loss 0.000000
# Iter 0244 | MSE Loss 0.000000
# Iter 0245 | MSE Loss 0.000000
# Iter 0246 | MSE Loss 0.000000
# Iter 0247 | MSE Loss 0.000000
# Iter 0248 | MSE Loss 0.000000
# Iter 0249 | MSE Loss 0.000000
# Iter 0250 | MSE Loss 0.000000
# Iter 0251 | MSE Loss 0.000000
# Iter 0252 | MSE Loss 0.000000
# Iter 0253 | MSE Loss 0.000000
# Iter 0254 | MSE Loss 0.000000
# Iter 0255 | MSE Loss 0.000000
# Iter 0256 | MSE Loss 0.000000
# Iter 0257 | MSE Loss 0.000000
# Iter 0258 | MSE Loss 0.000000
# Iter 0259 | MSE Loss 0.000000
# Iter 0260 | MSE Loss 0.000000
# Iter 0261 | MSE Loss 0.000000
# Iter 0262 | MSE Loss 0.000000
# Iter 0263 | MSE Loss 0.000000
# Iter 0264 | MSE Loss 0.000000
# Iter 0265 | MSE Loss 0.000000
# Iter 0266 | MSE Loss 0.000000
# Iter 0267 | MSE Loss 0.000000
# Iter 0268 | MSE Loss 0.000000
# Iter 0269 | MSE Loss 0.000000
# Iter 0270 | MSE Loss 0.000000
# Iter 0271 | MSE Loss 0.000000
# Iter 0272 | MSE Loss 0.000000
# Iter 0273 | MSE Loss 0.000000
# Iter 0274 | MSE Loss 0.000000
# Iter 0275 | MSE Loss 0.000000
# Iter 0276 | MSE Loss 0.000000
# Iter 0277 | MSE Loss 0.000000
# Iter 0278 | MSE Loss 0.000000
# Iter 0279 | MSE Loss 0.000000
# Iter 0280 | MSE Loss 0.000000
# Iter 0281 | MSE Loss 0.000000
# Iter 0282 | MSE Loss 0.000000
# Iter 0283 | MSE Loss 0.000000
# Iter 0284 | MSE Loss 0.000000
# Iter 0285 | MSE Loss 0.000000
# Iter 0286 | MSE Loss 0.000000
# Iter 0287 | MSE Loss 0.000000
# Iter 0288 | MSE Loss 0.000000
# Iter 0289 | MSE Loss 0.000000
# Iter 0290 | MSE Loss 0.000000
# Iter 0291 | MSE Loss 0.000000
# Iter 0292 | MSE Loss 0.000000
# Iter 0293 | MSE Loss 0.000000
# Iter 0294 | MSE Loss 0.000000
# Iter 0295 | MSE Loss 0.000000
# Iter 0296 | MSE Loss 0.000000
# Iter 0297 | MSE Loss 0.000000
# Iter 0298 | MSE Loss 0.000000
# Iter 0299 | MSE Loss 0.000000
# Iter 0300 | MSE Loss 0.000000
# Iter 0301 | MSE Loss 0.000000
# Iter 0302 | MSE Loss 0.000000
# Iter 0303 | MSE Loss 0.000000
# Iter 0304 | MSE Loss 0.000000
# Iter 0305 | MSE Loss 0.000000
# Iter 0306 | MSE Loss 0.000000
# Iter 0307 | MSE Loss 0.000000
# Iter 0308 | MSE Loss 0.000000
# Iter 0309 | MSE Loss 0.000000
# Iter 0310 | MSE Loss 0.000000
# Iter 0311 | MSE Loss 0.000000
# Iter 0312 | MSE Loss 0.000000
# Iter 0313 | MSE Loss 0.000000
# Iter 0314 | MSE Loss 0.000000
# Iter 0315 | MSE Loss 0.000000
# Iter 0316 | MSE Loss 0.000000
# Iter 0317 | MSE Loss 0.000000
# Iter 0318 | MSE Loss 0.000000
# Iter 0319 | MSE Loss 0.000000
# Iter 0320 | MSE Loss 0.000000
# Iter 0321 | MSE Loss 0.000000
# Iter 0322 | MSE Loss 0.000000
# Iter 0323 | MSE Loss 0.000000
# Iter 0324 | MSE Loss 0.000000
# Iter 0325 | MSE Loss 0.000000
# Iter 0326 | MSE Loss 0.000000
# Iter 0327 | MSE Loss 0.000000
# Iter 0328 | MSE Loss 0.000000
# Iter 0329 | MSE Loss 0.000000
# Iter 0330 | MSE Loss 0.000000
# Iter 0331 | MSE Loss 0.000000
# Iter 0332 | MSE Loss 0.000000
# Iter 0333 | MSE Loss 0.000000
# Iter 0334 | MSE Loss 0.000000
# Iter 0335 | MSE Loss 0.000000
# Iter 0336 | MSE Loss 0.000000
# Iter 0337 | MSE Loss 0.000000
# Iter 0338 | MSE Loss 0.000000
# Iter 0339 | MSE Loss 0.000000
# Iter 0340 | MSE Loss 0.000000
# Iter 0341 | MSE Loss 0.000000
# Iter 0342 | MSE Loss 0.000000
# Iter 0343 | MSE Loss 0.000000
# Iter 0344 | MSE Loss 0.000000
# Iter 0345 | MSE Loss 0.000000
# Iter 0346 | MSE Loss 0.000000
# Iter 0347 | MSE Loss 0.000000
# Iter 0348 | MSE Loss 0.000000
# Iter 0349 | MSE Loss 0.000000
# Iter 0350 | MSE Loss 0.000000
# Iter 0351 | MSE Loss 0.000000
# Iter 0352 | MSE Loss 0.000000
# Iter 0353 | MSE Loss 0.000000
# Iter 0354 | MSE Loss 0.000000
# Iter 0355 | MSE Loss 0.000000
# Iter 0356 | MSE Loss 0.000000
# Iter 0357 | MSE Loss 0.000000
# Iter 0358 | MSE Loss 0.000000
# Iter 0359 | MSE Loss 0.000000
# Iter 0360 | MSE Loss 0.000000
# Iter 0361 | MSE Loss 0.000000
# Iter 0362 | MSE Loss 0.000000
# Iter 0363 | MSE Loss 0.000000
# Iter 0364 | MSE Loss 0.000000
# Iter 0365 | MSE Loss 0.000000
# Iter 0366 | MSE Loss 0.000000
# Iter 0367 | MSE Loss 0.000000
# Iter 0368 | MSE Loss 0.000000
# Iter 0369 | MSE Loss 0.000000
# Iter 0370 | MSE Loss 0.000000
# Iter 0371 | MSE Loss 0.000000
# Iter 0372 | MSE Loss 0.000000
# Iter 0373 | MSE Loss 0.000000
# Iter 0374 | MSE Loss 0.000000
# Iter 0375 | MSE Loss 0.000000
# Iter 0376 | MSE Loss 0.000000
# Iter 0377 | MSE Loss 0.000000
# Iter 0378 | MSE Loss 0.000000
# Iter 0379 | MSE Loss 0.000000
# Iter 0380 | MSE Loss 0.000000
# Iter 0381 | MSE Loss 0.000000
# Iter 0382 | MSE Loss 0.000000
# Iter 0383 | MSE Loss 0.000000
# Iter 0384 | MSE Loss 0.000000
# Iter 0385 | MSE Loss 0.000000
# Iter 0386 | MSE Loss 0.000000
# Iter 0387 | MSE Loss 0.000000
# Iter 0388 | MSE Loss 0.000000
# Iter 0389 | MSE Loss 0.000000
# Iter 0390 | MSE Loss 0.000000
# Iter 0391 | MSE Loss 0.000000
# Iter 0392 | MSE Loss 0.000000
# Iter 0393 | MSE Loss 0.000000
# Iter 0394 | MSE Loss 0.000000
# Iter 0395 | MSE Loss 0.000000
# Iter 0396 | MSE Loss 0.000000
# Iter 0397 | MSE Loss 0.000000
# Iter 0398 | MSE Loss 0.000000
# Iter 0399 | MSE Loss 0.000000
# Iter 0400 | MSE Loss 0.000000
# Iter 0401 | MSE Loss 0.000000
# Iter 0402 | MSE Loss 0.000000
# Iter 0403 | MSE Loss 0.000000
# Iter 0404 | MSE Loss 0.000000
# Iter 0405 | MSE Loss 0.000000
# Iter 0406 | MSE Loss 0.000000
# Iter 0407 | MSE Loss 0.000000
# Iter 0408 | MSE Loss 0.000000
# Iter 0409 | MSE Loss 0.000000
# Iter 0410 | MSE Loss 0.000000
# Iter 0411 | MSE Loss 0.000000
# Iter 0412 | MSE Loss 0.000000
# Iter 0413 | MSE Loss 0.000000
# Iter 0414 | MSE Loss 0.000000
# Iter 0415 | MSE Loss 0.000000
# Iter 0416 | MSE Loss 0.000000
# Iter 0417 | MSE Loss 0.000000
# Iter 0418 | MSE Loss 0.000000
# Iter 0419 | MSE Loss 0.000000
# Iter 0420 | MSE Loss 0.000000
# Iter 0421 | MSE Loss 0.000000
# Iter 0422 | MSE Loss 0.000000
# Iter 0423 | MSE Loss 0.000000
# Iter 0424 | MSE Loss 0.000000
# Iter 0425 | MSE Loss 0.000000
# Iter 0426 | MSE Loss 0.000000
# Iter 0427 | MSE Loss 0.000000
# Iter 0428 | MSE Loss 0.000000
# Iter 0429 | MSE Loss 0.000000
# Iter 0430 | MSE Loss 0.000000
# Iter 0431 | MSE Loss 0.000000
# Iter 0432 | MSE Loss 0.000000
# Iter 0433 | MSE Loss 0.000000
# Iter 0434 | MSE Loss 0.000000
# Iter 0435 | MSE Loss 0.000000
# Iter 0436 | MSE Loss 0.000000
# Iter 0437 | MSE Loss 0.000000
# Iter 0438 | MSE Loss 0.000000
# Iter 0439 | MSE Loss 0.000000
# Iter 0440 | MSE Loss 0.000000
# Iter 0441 | MSE Loss 0.000000
# Iter 0442 | MSE Loss 0.000000
# Iter 0443 | MSE Loss 0.000000
# Iter 0444 | MSE Loss 0.000000
# Iter 0445 | MSE Loss 0.000000
# Iter 0446 | MSE Loss 0.000000
# Iter 0447 | MSE Loss 0.000000
# Iter 0448 | MSE Loss 0.000000
# Iter 0449 | MSE Loss 0.000000
# Iter 0450 | MSE Loss 0.000000
# Iter 0451 | MSE Loss 0.000000
# Iter 0452 | MSE Loss 0.000000
# Iter 0453 | MSE Loss 0.000000
# Iter 0454 | MSE Loss 0.000000
# Iter 0455 | MSE Loss 0.000000
# Iter 0456 | MSE Loss 0.000000
# Iter 0457 | MSE Loss 0.000000
# Iter 0458 | MSE Loss 0.000000
# Iter 0459 | MSE Loss 0.000000
# Iter 0460 | MSE Loss 0.000000
# Iter 0461 | MSE Loss 0.000000
# Iter 0462 | MSE Loss 0.000000
# Iter 0463 | MSE Loss 0.000000
# Iter 0464 | MSE Loss 0.000000
# Iter 0465 | MSE Loss 0.000000
# Iter 0466 | MSE Loss 0.000000
# Iter 0467 | MSE Loss 0.000000
# Iter 0468 | MSE Loss 0.000000
# Iter 0469 | MSE Loss 0.000000
# Iter 0470 | MSE Loss 0.000000
# Iter 0471 | MSE Loss 0.000000
# Iter 0472 | MSE Loss 0.000000
# Iter 0473 | MSE Loss 0.000000
# Iter 0474 | MSE Loss 0.000000
# Iter 0475 | MSE Loss 0.000000
# Iter 0476 | MSE Loss 0.000000
# Iter 0477 | MSE Loss 0.000000
# Iter 0478 | MSE Loss 0.000000
# Iter 0479 | MSE Loss 0.000000
# Iter 0480 | MSE Loss 0.000000
# Iter 0481 | MSE Loss 0.000000
# Iter 0482 | MSE Loss 0.000000
# Iter 0483 | MSE Loss 0.000000
# Iter 0484 | MSE Loss 0.000000
# Iter 0485 | MSE Loss 0.000000
# Iter 0486 | MSE Loss 0.000000
# Iter 0487 | MSE Loss 0.000000
# Iter 0488 | MSE Loss 0.000000
# Iter 0489 | MSE Loss 0.000000
# Iter 0490 | MSE Loss 0.000000
# Iter 0491 | MSE Loss 0.000000
# Iter 0492 | MSE Loss 0.000000
# Iter 0493 | MSE Loss 0.000000
# Iter 0494 | MSE Loss 0.000000
# Iter 0495 | MSE Loss 0.000000
# Iter 0496 | MSE Loss 0.000000
# Iter 0497 | MSE Loss 0.000000
# Iter 0498 | MSE Loss 0.000000
# Iter 0499 | MSE Loss 0.000000
# Iter 0500 | MSE Loss 0.000000
# Iter 0501 | MSE Loss 0.000000
# Iter 0502 | MSE Loss 0.000000
# Iter 0503 | MSE Loss 0.000000
# Iter 0504 | MSE Loss 0.000000
# Iter 0505 | MSE Loss 0.000000
# Iter 0506 | MSE Loss 0.000000
# Iter 0507 | MSE Loss 0.000000
# Iter 0508 | MSE Loss 0.000000
# Iter 0509 | MSE Loss 0.000000
# Iter 0510 | MSE Loss 0.000000
# Iter 0511 | MSE Loss 0.000000
# Iter 0512 | MSE Loss 0.000000
# Iter 0513 | MSE Loss 0.000000
# Iter 0514 | MSE Loss 0.000000
# Iter 0515 | MSE Loss 0.000000
# Iter 0516 | MSE Loss 0.000000
# Iter 0517 | MSE Loss 0.000000
# Iter 0518 | MSE Loss 0.000000
# Iter 0519 | MSE Loss 0.000000
# Iter 0520 | MSE Loss 0.000000
# Iter 0521 | MSE Loss 0.000000
# Iter 0522 | MSE Loss 0.000000
# Iter 0523 | MSE Loss 0.000000
# Iter 0524 | MSE Loss 0.000000
# Iter 0525 | MSE Loss 0.000000
# Iter 0526 | MSE Loss 0.000000
# Iter 0527 | MSE Loss 0.000000
# Iter 0528 | MSE Loss 0.000000
# Iter 0529 | MSE Loss 0.000000
# Iter 0530 | MSE Loss 0.000000
# Iter 0531 | MSE Loss 0.000000
# Iter 0532 | MSE Loss 0.000000
# Iter 0533 | MSE Loss 0.000000
# Iter 0534 | MSE Loss 0.000000
# Iter 0535 | MSE Loss 0.000000
# Iter 0536 | MSE Loss 0.000000
# Iter 0537 | MSE Loss 0.000000
# Iter 0538 | MSE Loss 0.000000
# Iter 0539 | MSE Loss 0.000000
# Iter 0540 | MSE Loss 0.000000
# Iter 0541 | MSE Loss 0.000000
# Iter 0542 | MSE Loss 0.000000
# Iter 0543 | MSE Loss 0.000000
# Iter 0544 | MSE Loss 0.000000
# Iter 0545 | MSE Loss 0.000000
# Iter 0546 | MSE Loss 0.000000
# Iter 0547 | MSE Loss 0.000000
# Iter 0548 | MSE Loss 0.000000
# Iter 0549 | MSE Loss 0.000000
# Iter 0550 | MSE Loss 0.000000
# Iter 0551 | MSE Loss 0.000000
# Iter 0552 | MSE Loss 0.000000
# Iter 0553 | MSE Loss 0.000000
# Iter 0554 | MSE Loss 0.000000
# Iter 0555 | MSE Loss 0.000000
# Iter 0556 | MSE Loss 0.000000
# Iter 0557 | MSE Loss 0.000000
# Iter 0558 | MSE Loss 0.000000
# Iter 0559 | MSE Loss 0.000000
# Iter 0560 | MSE Loss 0.000000
# Iter 0561 | MSE Loss 0.000000
# Iter 0562 | MSE Loss 0.000000
# Iter 0563 | MSE Loss 0.000000
# Iter 0564 | MSE Loss 0.000000
# Iter 0565 | MSE Loss 0.000000
# Iter 0566 | MSE Loss 0.000000
# Iter 0567 | MSE Loss 0.000000
# Iter 0568 | MSE Loss 0.000000
# Iter 0569 | MSE Loss 0.000000
# Iter 0570 | MSE Loss 0.000000
# Iter 0571 | MSE Loss 0.000000
# Iter 0572 | MSE Loss 0.000000
# Iter 0573 | MSE Loss 0.000000
# Iter 0574 | MSE Loss 0.000000
# Iter 0575 | MSE Loss 0.000000
# Iter 0576 | MSE Loss 0.000000
# Iter 0577 | MSE Loss 0.000000
# Iter 0578 | MSE Loss 0.000000
# Iter 0579 | MSE Loss 0.000000
# Iter 0580 | MSE Loss 0.000000
# Iter 0581 | MSE Loss 0.000000
# Iter 0582 | MSE Loss 0.000000
# Iter 0583 | MSE Loss 0.000000
# Iter 0584 | MSE Loss 0.000000
# Iter 0585 | MSE Loss 0.000000
# Iter 0586 | MSE Loss 0.000000
# Iter 0587 | MSE Loss 0.000000
# Iter 0588 | MSE Loss 0.000000
# Iter 0589 | MSE Loss 0.000000
# Iter 0590 | MSE Loss 0.000000
# Iter 0591 | MSE Loss 0.000000
# Iter 0592 | MSE Loss 0.000000
# Iter 0593 | MSE Loss 0.000000
# Iter 0594 | MSE Loss 0.000000
# Iter 0595 | MSE Loss 0.000000
# Iter 0596 | MSE Loss 0.000000
# Iter 0597 | MSE Loss 0.000000
# Iter 0598 | MSE Loss 0.000000
# Iter 0599 | MSE Loss 0.000000
# Iter 0600 | MSE Loss 0.000000
# Iter 0601 | MSE Loss 0.000000
# Iter 0602 | MSE Loss 0.000000
# Iter 0603 | MSE Loss 0.000000
# Iter 0604 | MSE Loss 0.000000
# Iter 0605 | MSE Loss 0.000000
# Iter 0606 | MSE Loss 0.000000
# Iter 0607 | MSE Loss 0.000000
# Iter 0608 | MSE Loss 0.000000
# Iter 0609 | MSE Loss 0.000000
# Iter 0610 | MSE Loss 0.000000
# Iter 0611 | MSE Loss 0.000000
# Iter 0612 | MSE Loss 0.000000
# Iter 0613 | MSE Loss 0.000000
# Iter 0614 | MSE Loss 0.000000
# Iter 0615 | MSE Loss 0.000000
# Iter 0616 | MSE Loss 0.000000
# Iter 0617 | MSE Loss 0.000000
# Iter 0618 | MSE Loss 0.000000
# Iter 0619 | MSE Loss 0.000000
# Iter 0620 | MSE Loss 0.000000
# Iter 0621 | MSE Loss 0.000000
# Iter 0622 | MSE Loss 0.000000
# Iter 0623 | MSE Loss 0.000000
# Iter 0624 | MSE Loss 0.000000
# Iter 0625 | MSE Loss 0.000000
# Iter 0626 | MSE Loss 0.000000
# Iter 0627 | MSE Loss 0.000000
# Iter 0628 | MSE Loss 0.000000
# Iter 0629 | MSE Loss 0.000000
# Iter 0630 | MSE Loss 0.000000
# Iter 0631 | MSE Loss 0.000000
# Iter 0632 | MSE Loss 0.000000
# Iter 0633 | MSE Loss 0.000000
# Iter 0634 | MSE Loss 0.000000
# Iter 0635 | MSE Loss 0.000000
# Iter 0636 | MSE Loss 0.000000
# Iter 0637 | MSE Loss 0.000000
# Iter 0638 | MSE Loss 0.000000
# Iter 0639 | MSE Loss 0.000000
# Iter 0640 | MSE Loss 0.000000
# Iter 0641 | MSE Loss 0.000000
# Iter 0642 | MSE Loss 0.000000
# Iter 0643 | MSE Loss 0.000000
# Iter 0644 | MSE Loss 0.000000
# Iter 0645 | MSE Loss 0.000000
# Iter 0646 | MSE Loss 0.000000
# Iter 0647 | MSE Loss 0.000000
# Iter 0648 | MSE Loss 0.000000
# Iter 0649 | MSE Loss 0.000000
# Iter 0650 | MSE Loss 0.000000
# Iter 0651 | MSE Loss 0.000000
# Iter 0652 | MSE Loss 0.000000
# Iter 0653 | MSE Loss 0.000000
# Iter 0654 | MSE Loss 0.000000
# Iter 0655 | MSE Loss 0.000000
# Iter 0656 | MSE Loss 0.000000
# Iter 0657 | MSE Loss 0.000000
# Iter 0658 | MSE Loss 0.000000
# Iter 0659 | MSE Loss 0.000000
# Iter 0660 | MSE Loss 0.000000
# Iter 0661 | MSE Loss 0.000000
# Iter 0662 | MSE Loss 0.000000
# Iter 0663 | MSE Loss 0.000000
# Iter 0664 | MSE Loss 0.000000
# Iter 0665 | MSE Loss 0.000000
# Iter 0666 | MSE Loss 0.000000
# Iter 0667 | MSE Loss 0.000000
# Iter 0668 | MSE Loss 0.000000
# Iter 0669 | MSE Loss 0.000000
# Iter 0670 | MSE Loss 0.000000
# Iter 0671 | MSE Loss 0.000000
# Iter 0672 | MSE Loss 0.000000
# Iter 0673 | MSE Loss 0.000000
# Iter 0674 | MSE Loss 0.000000
# Iter 0675 | MSE Loss 0.000000
# Iter 0676 | MSE Loss 0.000000
# Iter 0677 | MSE Loss 0.000000
# Iter 0678 | MSE Loss 0.000000
# Iter 0679 | MSE Loss 0.000000
# Iter 0680 | MSE Loss 0.000000
# Iter 0681 | MSE Loss 0.000000
# Iter 0682 | MSE Loss 0.000000
# Iter 0683 | MSE Loss 0.000000
# Iter 0684 | MSE Loss 0.000000
# Iter 0685 | MSE Loss 0.000000
# Iter 0686 | MSE Loss 0.000000
# Iter 0687 | MSE Loss 0.000000
# Iter 0688 | MSE Loss 0.000000
# Iter 0689 | MSE Loss 0.000000
# Iter 0690 | MSE Loss 0.000000
# Iter 0691 | MSE Loss 0.000000
# Iter 0692 | MSE Loss 0.000000
# Iter 0693 | MSE Loss 0.000000
# Iter 0694 | MSE Loss 0.000000
# Iter 0695 | MSE Loss 0.000000
# Iter 0696 | MSE Loss 0.000000
# Iter 0697 | MSE Loss 0.000000
# Iter 0698 | MSE Loss 0.000000
# Iter 0699 | MSE Loss 0.000000
# Iter 0700 | MSE Loss 0.000000
# Iter 0701 | MSE Loss 0.000000
# Iter 0702 | MSE Loss 0.000000
# Iter 0703 | MSE Loss 0.000000
# Iter 0704 | MSE Loss 0.000000
# Iter 0705 | MSE Loss 0.000000
# Iter 0706 | MSE Loss 0.000000
# Iter 0707 | MSE Loss 0.000000
# Iter 0708 | MSE Loss 0.000000
# Iter 0709 | MSE Loss 0.000000
# Iter 0710 | MSE Loss 0.000000
# Iter 0711 | MSE Loss 0.000000
# Iter 0712 | MSE Loss 0.000000
# Iter 0713 | MSE Loss 0.000000
# Iter 0714 | MSE Loss 0.000000
# Iter 0715 | MSE Loss 0.000000
# Iter 0716 | MSE Loss 0.000000
# Iter 0717 | MSE Loss 0.000000
# Iter 0718 | MSE Loss 0.000000
# Iter 0719 | MSE Loss 0.000000
# Iter 0720 | MSE Loss 0.000000
# Iter 0721 | MSE Loss 0.000000
# Iter 0722 | MSE Loss 0.000000
# Iter 0723 | MSE Loss 0.000000
# Iter 0724 | MSE Loss 0.000000
# Iter 0725 | MSE Loss 0.000000
# Iter 0726 | MSE Loss 0.000000
# Iter 0727 | MSE Loss 0.000000
# Iter 0728 | MSE Loss 0.000000
# Iter 0729 | MSE Loss 0.000000
# Iter 0730 | MSE Loss 0.000000
# Iter 0731 | MSE Loss 0.000000
# Iter 0732 | MSE Loss 0.000000
# Iter 0733 | MSE Loss 0.000000
# Iter 0734 | MSE Loss 0.000000
# Iter 0735 | MSE Loss 0.000000
# Iter 0736 | MSE Loss 0.000000
# Iter 0737 | MSE Loss 0.000000
# Iter 0738 | MSE Loss 0.000000
# Iter 0739 | MSE Loss 0.000000
# Iter 0740 | MSE Loss 0.000000
# Iter 0741 | MSE Loss 0.000000
# Iter 0742 | MSE Loss 0.000000
# Iter 0743 | MSE Loss 0.000000
# Iter 0744 | MSE Loss 0.000000
# Iter 0745 | MSE Loss 0.000000
# Iter 0746 | MSE Loss 0.000000
# Iter 0747 | MSE Loss 0.000000
# Iter 0748 | MSE Loss 0.000000
# Iter 0749 | MSE Loss 0.000000
# Iter 0750 | MSE Loss 0.000000
# Iter 0751 | MSE Loss 0.000000
# Iter 0752 | MSE Loss 0.000000
# Iter 0753 | MSE Loss 0.000000
# Iter 0754 | MSE Loss 0.000000
# Iter 0755 | MSE Loss 0.000000
# Iter 0756 | MSE Loss 0.000000
# Iter 0757 | MSE Loss 0.000000
# Iter 0758 | MSE Loss 0.000000
# Iter 0759 | MSE Loss 0.000000
# Iter 0760 | MSE Loss 0.000000
# Iter 0761 | MSE Loss 0.000000
# Iter 0762 | MSE Loss 0.000000
# Iter 0763 | MSE Loss 0.000000
# Iter 0764 | MSE Loss 0.000000
# Iter 0765 | MSE Loss 0.000000
# Iter 0766 | MSE Loss 0.000000
# Iter 0767 | MSE Loss 0.000000
# Iter 0768 | MSE Loss 0.000000
# Iter 0769 | MSE Loss 0.000000
# Iter 0770 | MSE Loss 0.000000
# Iter 0771 | MSE Loss 0.000000
# Iter 0772 | MSE Loss 0.000000
# Iter 0773 | MSE Loss 0.000000
# Iter 0774 | MSE Loss 0.000000
# Iter 0775 | MSE Loss 0.000000
# Iter 0776 | MSE Loss 0.000000
# Iter 0777 | MSE Loss 0.000000
# Iter 0778 | MSE Loss 0.000000
# Iter 0779 | MSE Loss 0.000000
# Iter 0780 | MSE Loss 0.000000
# Iter 0781 | MSE Loss 0.000000
# Iter 0782 | MSE Loss 0.000000
# Iter 0783 | MSE Loss 0.000000
# Iter 0784 | MSE Loss 0.000000
# Iter 0785 | MSE Loss 0.000000
# Iter 0786 | MSE Loss 0.000000
# Iter 0787 | MSE Loss 0.000000
# Iter 0788 | MSE Loss 0.000000
# Iter 0789 | MSE Loss 0.000000
# Iter 0790 | MSE Loss 0.000000
# Iter 0791 | MSE Loss 0.000000
# Iter 0792 | MSE Loss 0.000000
# Iter 0793 | MSE Loss 0.000000
# Iter 0794 | MSE Loss 0.000000
# Iter 0795 | MSE Loss 0.000000
# Iter 0796 | MSE Loss 0.000000
# Iter 0797 | MSE Loss 0.000000
# Iter 0798 | MSE Loss 0.000000
# Iter 0799 | MSE Loss 0.000000
# Iter 0800 | MSE Loss 0.000000
# Iter 0801 | MSE Loss 0.000000
# Iter 0802 | MSE Loss 0.000000
# Iter 0803 | MSE Loss 0.000000
# Iter 0804 | MSE Loss 0.000000
# Iter 0805 | MSE Loss 0.000000
# Iter 0806 | MSE Loss 0.000000
# Iter 0807 | MSE Loss 0.000000
# Iter 0808 | MSE Loss 0.000000
# Iter 0809 | MSE Loss 0.000000
# Iter 0810 | MSE Loss 0.000000
# Iter 0811 | MSE Loss 0.000000
# Iter 0812 | MSE Loss 0.000000
# Iter 0813 | MSE Loss 0.000000
# Iter 0814 | MSE Loss 0.000000
# Iter 0815 | MSE Loss 0.000000
# Iter 0816 | MSE Loss 0.000000
# Iter 0817 | MSE Loss 0.000000
# Iter 0818 | MSE Loss 0.000000
# Iter 0819 | MSE Loss 0.000000
# Iter 0820 | MSE Loss 0.000000
# Iter 0821 | MSE Loss 0.000000
# Iter 0822 | MSE Loss 0.000000
# Iter 0823 | MSE Loss 0.000000
# Iter 0824 | MSE Loss 0.000000
# Iter 0825 | MSE Loss 0.000000
# Iter 0826 | MSE Loss 0.000000
# Iter 0827 | MSE Loss 0.000000
# Iter 0828 | MSE Loss 0.000000
# Iter 0829 | MSE Loss 0.000000
# Iter 0830 | MSE Loss 0.000000
# Iter 0831 | MSE Loss 0.000000
# Iter 0832 | MSE Loss 0.000000
# Iter 0833 | MSE Loss 0.000000
# Iter 0834 | MSE Loss 0.000000
# Iter 0835 | MSE Loss 0.000000
# Iter 0836 | MSE Loss 0.000000
# Iter 0837 | MSE Loss 0.000000
# Iter 0838 | MSE Loss 0.000000
# Iter 0839 | MSE Loss 0.000000
# Iter 0840 | MSE Loss 0.000000
# Iter 0841 | MSE Loss 0.000000
# Iter 0842 | MSE Loss 0.000000
# Iter 0843 | MSE Loss 0.000000
# Iter 0844 | MSE Loss 0.000000
# Iter 0845 | MSE Loss 0.000000
# Iter 0846 | MSE Loss 0.000000
# Iter 0847 | MSE Loss 0.000000
# Iter 0848 | MSE Loss 0.000000
# Iter 0849 | MSE Loss 0.000000
# Iter 0850 | MSE Loss 0.000000
# Iter 0851 | MSE Loss 0.000000
# Iter 0852 | MSE Loss 0.000000
# Iter 0853 | MSE Loss 0.000000
# Iter 0854 | MSE Loss 0.000000
# Iter 0855 | MSE Loss 0.000000
# Iter 0856 | MSE Loss 0.000000
# Iter 0857 | MSE Loss 0.000000
# Iter 0858 | MSE Loss 0.000000
# Iter 0859 | MSE Loss 0.000000
# Iter 0860 | MSE Loss 0.000000
# Iter 0861 | MSE Loss 0.000000
# Iter 0862 | MSE Loss 0.000000
# Iter 0863 | MSE Loss 0.000000
# Iter 0864 | MSE Loss 0.000000
# Iter 0865 | MSE Loss 0.000000
# Iter 0866 | MSE Loss 0.000000
# Iter 0867 | MSE Loss 0.000000
# Iter 0868 | MSE Loss 0.000000
# Iter 0869 | MSE Loss 0.000000
# Iter 0870 | MSE Loss 0.000000
# Iter 0871 | MSE Loss 0.000000
# Iter 0872 | MSE Loss 0.000000
# Iter 0873 | MSE Loss 0.000000
# Iter 0874 | MSE Loss 0.000000
# Iter 0875 | MSE Loss 0.000000
# Iter 0876 | MSE Loss 0.000000
# Iter 0877 | MSE Loss 0.000000
# Iter 0878 | MSE Loss 0.000000
# Iter 0879 | MSE Loss 0.000000
# Iter 0880 | MSE Loss 0.000000
# Iter 0881 | MSE Loss 0.000000
# Iter 0882 | MSE Loss 0.000000
# Iter 0883 | MSE Loss 0.000000
# Iter 0884 | MSE Loss 0.000000
# Iter 0885 | MSE Loss 0.000000
# Iter 0886 | MSE Loss 0.000000
# Iter 0887 | MSE Loss 0.000000
# Iter 0888 | MSE Loss 0.000000
# Iter 0889 | MSE Loss 0.000000
# Iter 0890 | MSE Loss 0.000000
# Iter 0891 | MSE Loss 0.000000
# Iter 0892 | MSE Loss 0.000000
# Iter 0893 | MSE Loss 0.000000
# Iter 0894 | MSE Loss 0.000000
# Iter 0895 | MSE Loss 0.000000
# Iter 0896 | MSE Loss 0.000000
# Iter 0897 | MSE Loss 0.000000
# Iter 0898 | MSE Loss 0.000000
# Iter 0899 | MSE Loss 0.000000
# Iter 0900 | MSE Loss 0.000000
# Iter 0901 | MSE Loss 0.000000
# Iter 0902 | MSE Loss 0.000000
# Iter 0903 | MSE Loss 0.000000
# Iter 0904 | MSE Loss 0.000000
# Iter 0905 | MSE Loss 0.000000
# Iter 0906 | MSE Loss 0.000000
# Iter 0907 | MSE Loss 0.000000
# Iter 0908 | MSE Loss 0.000000
# Iter 0909 | MSE Loss 0.000000
# Iter 0910 | MSE Loss 0.000000
# Iter 0911 | MSE Loss 0.000000
# Iter 0912 | MSE Loss 0.000000
# Iter 0913 | MSE Loss 0.000000
# Iter 0914 | MSE Loss 0.000000
# Iter 0915 | MSE Loss 0.000000
# Iter 0916 | MSE Loss 0.000000
# Iter 0917 | MSE Loss 0.000000
# Iter 0918 | MSE Loss 0.000000
# Iter 0919 | MSE Loss 0.000000
# Iter 0920 | MSE Loss 0.000000
# Iter 0921 | MSE Loss 0.000000
# Iter 0922 | MSE Loss 0.000000
# Iter 0923 | MSE Loss 0.000000
# Iter 0924 | MSE Loss 0.000000
# Iter 0925 | MSE Loss 0.000000
# Iter 0926 | MSE Loss 0.000000
# Iter 0927 | MSE Loss 0.000000
# Iter 0928 | MSE Loss 0.000000
# Iter 0929 | MSE Loss 0.000000
# Iter 0930 | MSE Loss 0.000000
# Iter 0931 | MSE Loss 0.000000
# Iter 0932 | MSE Loss 0.000000
# Iter 0933 | MSE Loss 0.000000
# Iter 0934 | MSE Loss 0.000000
# Iter 0935 | MSE Loss 0.000000
# Iter 0936 | MSE Loss 0.000000
# Iter 0937 | MSE Loss 0.000000
# Iter 0938 | MSE Loss 0.000000
# Iter 0939 | MSE Loss 0.000000
# Iter 0940 | MSE Loss 0.000000
# Iter 0941 | MSE Loss 0.000000
# Iter 0942 | MSE Loss 0.000000
# Iter 0943 | MSE Loss 0.000000
# Iter 0944 | MSE Loss 0.000000
# Iter 0945 | MSE Loss 0.000000
# Iter 0946 | MSE Loss 0.000000
# Iter 0947 | MSE Loss 0.000000
# Iter 0948 | MSE Loss 0.000000
# Iter 0949 | MSE Loss 0.000000
# Iter 0950 | MSE Loss 0.000000
# Iter 0951 | MSE Loss 0.000000
# Iter 0952 | MSE Loss 0.000000
# Iter 0953 | MSE Loss 0.000000
# Iter 0954 | MSE Loss 0.000000
# Iter 0955 | MSE Loss 0.000000
# Iter 0956 | MSE Loss 0.000000
# Iter 0957 | MSE Loss 0.000000
# Iter 0958 | MSE Loss 0.000000
# Iter 0959 | MSE Loss 0.000000
# Iter 0960 | MSE Loss 0.000000
# Iter 0961 | MSE Loss 0.000000
# Iter 0962 | MSE Loss 0.000000
# Iter 0963 | MSE Loss 0.000000
# Iter 0964 | MSE Loss 0.000000
# Iter 0965 | MSE Loss 0.000000
# Iter 0966 | MSE Loss 0.000000
# Iter 0967 | MSE Loss 0.000000
# Iter 0968 | MSE Loss 0.000000
# Iter 0969 | MSE Loss 0.000000
# Iter 0970 | MSE Loss 0.000000
# Iter 0971 | MSE Loss 0.000000
# Iter 0972 | MSE Loss 0.000000
# Iter 0973 | MSE Loss 0.000000
# Iter 0974 | MSE Loss 0.000000
# Iter 0975 | MSE Loss 0.000000
# Iter 0976 | MSE Loss 0.000000
# Iter 0977 | MSE Loss 0.000000
# Iter 0978 | MSE Loss 0.000000
# Iter 0979 | MSE Loss 0.000000
# Iter 0980 | MSE Loss 0.000000
# Iter 0981 | MSE Loss 0.000000
# Iter 0982 | MSE Loss 0.000000
# Iter 0983 | MSE Loss 0.000000
# Iter 0984 | MSE Loss 0.000000
# Iter 0985 | MSE Loss 0.000000
# Iter 0986 | MSE Loss 0.000000
# Iter 0987 | MSE Loss 0.000000
# Iter 0988 | MSE Loss 0.000000
# Iter 0989 | MSE Loss 0.000000
# Iter 0990 | MSE Loss 0.000000
# Iter 0991 | MSE Loss 0.000000
# Iter 0992 | MSE Loss 0.000000
# Iter 0993 | MSE Loss 0.000000
# Iter 0994 | MSE Loss 0.000000
# Iter 0995 | MSE Loss 0.000000
# Iter 0996 | MSE Loss 0.000000
# Iter 0997 | MSE Loss 0.000000
# Iter 0998 | MSE Loss 0.000000
# Iter 0999 | MSE Loss 0.000000
# Iter 1000 | MSE Loss 0.000000
# Iter 1001 | MSE Loss 0.000000
# Iter 1002 | MSE Loss 0.000000
# Iter 1003 | MSE Loss 0.000000
# Iter 1004 | MSE Loss 0.000000
# Iter 1005 | MSE Loss 0.000000
# Iter 1006 | MSE Loss 0.000000
# Iter 1007 | MSE Loss 0.000000
# Iter 1008 | MSE Loss 0.000000
# Iter 1009 | MSE Loss 0.000000
# Iter 1010 | MSE Loss 0.000000
# Iter 1011 | MSE Loss 0.000000
# Iter 1012 | MSE Loss 0.000000
# Iter 1013 | MSE Loss 0.000000
# Iter 1014 | MSE Loss 0.000000
# Iter 1015 | MSE Loss 0.000000
# Iter 1016 | MSE Loss 0.000000
# Iter 1017 | MSE Loss 0.000000
# Iter 1018 | MSE Loss 0.000000
# Iter 1019 | MSE Loss 0.000000
# Iter 1020 | MSE Loss 0.000000
# Iter 1021 | MSE Loss 0.000000
# Iter 1022 | MSE Loss 0.000000
# Iter 1023 | MSE Loss 0.000000
# Iter 1024 | MSE Loss 0.000000
# Iter 1025 | MSE Loss 0.000000
# Iter 1026 | MSE Loss 0.000000
# Iter 1027 | MSE Loss 0.000000
# Iter 1028 | MSE Loss 0.000000
# Iter 1029 | MSE Loss 0.000000
# Iter 1030 | MSE Loss 0.000000
# Iter 1031 | MSE Loss 0.000000
# Iter 1032 | MSE Loss 0.000000
# Iter 1033 | MSE Loss 0.000000
# Iter 1034 | MSE Loss 0.000000
# Iter 1035 | MSE Loss 0.000000
# Iter 1036 | MSE Loss 0.000000
# Iter 1037 | MSE Loss 0.000000
# Iter 1038 | MSE Loss 0.000000
# Iter 1039 | MSE Loss 0.000000
# Iter 1040 | MSE Loss 0.000000
# Iter 1041 | MSE Loss 0.000000
# Iter 1042 | MSE Loss 0.000000
# Iter 1043 | MSE Loss 0.000000
# Iter 1044 | MSE Loss 0.000000
# Iter 1045 | MSE Loss 0.000000
# Iter 1046 | MSE Loss 0.000000
# Iter 1047 | MSE Loss 0.000000
# Iter 1048 | MSE Loss 0.000000
# Iter 1049 | MSE Loss 0.000000
# Iter 1050 | MSE Loss 0.000000
# Iter 1051 | MSE Loss 0.000000
# Iter 1052 | MSE Loss 0.000000
# Iter 1053 | MSE Loss 0.000000
# Iter 1054 | MSE Loss 0.000000
# Iter 1055 | MSE Loss 0.000000
# Iter 1056 | MSE Loss 0.000000
# Iter 1057 | MSE Loss 0.000000
# Iter 1058 | MSE Loss 0.000000
# Iter 1059 | MSE Loss 0.000000
# Iter 1060 | MSE Loss 0.000000
# Iter 1061 | MSE Loss 0.000000
# Iter 1062 | MSE Loss 0.000000
# Iter 1063 | MSE Loss 0.000000
# Iter 1064 | MSE Loss 0.000000
# Iter 1065 | MSE Loss 0.000000
# Iter 1066 | MSE Loss 0.000000
# Iter 1067 | MSE Loss 0.000000
# Iter 1068 | MSE Loss 0.000000
# Iter 1069 | MSE Loss 0.000000
# Iter 1070 | MSE Loss 0.000000
# Iter 1071 | MSE Loss 0.000000
# Iter 1072 | MSE Loss 0.000000
# Iter 1073 | MSE Loss 0.000000
# Iter 1074 | MSE Loss 0.000000
# Iter 1075 | MSE Loss 0.000000
# Iter 1076 | MSE Loss 0.000000
# Iter 1077 | MSE Loss 0.000000
# Iter 1078 | MSE Loss 0.000000
# Iter 1079 | MSE Loss 0.000000
# Iter 1080 | MSE Loss 0.000000
# Iter 1081 | MSE Loss 0.000000
# Iter 1082 | MSE Loss 0.000000
# Iter 1083 | MSE Loss 0.000000
# Iter 1084 | MSE Loss 0.000000
# Iter 1085 | MSE Loss 0.000000
# Iter 1086 | MSE Loss 0.000000
# Iter 1087 | MSE Loss 0.000000
# Iter 1088 | MSE Loss 0.000000
# Iter 1089 | MSE Loss 0.000000
# Iter 1090 | MSE Loss 0.000000
# Iter 1091 | MSE Loss 0.000000
# Iter 1092 | MSE Loss 0.000000
# Iter 1093 | MSE Loss 0.000000
# Iter 1094 | MSE Loss 0.000000
# Iter 1095 | MSE Loss 0.000000
# Iter 1096 | MSE Loss 0.000000
# Iter 1097 | MSE Loss 0.000000
# Iter 1098 | MSE Loss 0.000000
# Iter 1099 | MSE Loss 0.000000
# Iter 1100 | MSE Loss 0.000000
# Iter 1101 | MSE Loss 0.000000
# Iter 1102 | MSE Loss 0.000000
# Iter 1103 | MSE Loss 0.000000
# Iter 1104 | MSE Loss 0.000000
# Iter 1105 | MSE Loss 0.000000
# Iter 1106 | MSE Loss 0.000000
# Iter 1107 | MSE Loss 0.000000
# Iter 1108 | MSE Loss 0.000000
# Iter 1109 | MSE Loss 0.000000
# Iter 1110 | MSE Loss 0.000000
# Iter 1111 | MSE Loss 0.000000
# Iter 1112 | MSE Loss 0.000000
# Iter 1113 | MSE Loss 0.000000
# Iter 1114 | MSE Loss 0.000000
# Iter 1115 | MSE Loss 0.000000
# Iter 1116 | MSE Loss 0.000000
# Iter 1117 | MSE Loss 0.000000
# Iter 1118 | MSE Loss 0.000000
# Iter 1119 | MSE Loss 0.000000
# Iter 1120 | MSE Loss 0.000000
# Iter 1121 | MSE Loss 0.000000
# Iter 1122 | MSE Loss 0.000000
# Iter 1123 | MSE Loss 0.000000
# Iter 1124 | MSE Loss 0.000000
# Iter 1125 | MSE Loss 0.000000
# Iter 1126 | MSE Loss 0.000000
# Iter 1127 | MSE Loss 0.000000
# Iter 1128 | MSE Loss 0.000000
# Iter 1129 | MSE Loss 0.000000
# Iter 1130 | MSE Loss 0.000000
# Iter 1131 | MSE Loss 0.000000
# Iter 1132 | MSE Loss 0.000000
# Iter 1133 | MSE Loss 0.000000
# Iter 1134 | MSE Loss 0.000000
# Iter 1135 | MSE Loss 0.000000
# Iter 1136 | MSE Loss 0.000000
# Iter 1137 | MSE Loss 0.000000
# Iter 1138 | MSE Loss 0.000000
# Iter 1139 | MSE Loss 0.000000
# Iter 1140 | MSE Loss 0.000000
# Iter 1141 | MSE Loss 0.000000
# Iter 1142 | MSE Loss 0.000000
# Iter 1143 | MSE Loss 0.000000
# Iter 1144 | MSE Loss 0.000000
# Iter 1145 | MSE Loss 0.000000
# Iter 1146 | MSE Loss 0.000000
# Iter 1147 | MSE Loss 0.000000
# Iter 1148 | MSE Loss 0.000000
# Iter 1149 | MSE Loss 0.000000
# Iter 1150 | MSE Loss 0.000000
# Iter 1151 | MSE Loss 0.000000
# Iter 1152 | MSE Loss 0.000000
# Iter 1153 | MSE Loss 0.000000
# Iter 1154 | MSE Loss 0.000000
# Iter 1155 | MSE Loss 0.000000
# Iter 1156 | MSE Loss 0.000000
# Iter 1157 | MSE Loss 0.000000
# Iter 1158 | MSE Loss 0.000000
# Iter 1159 | MSE Loss 0.000000
# Iter 1160 | MSE Loss 0.000000
# Iter 1161 | MSE Loss 0.000000
# Iter 1162 | MSE Loss 0.000000
# Iter 1163 | MSE Loss 0.000000
# Iter 1164 | MSE Loss 0.000000
# Iter 1165 | MSE Loss 0.000000
# Iter 1166 | MSE Loss 0.000000
# Iter 1167 | MSE Loss 0.000000
# Iter 1168 | MSE Loss 0.000000
# Iter 1169 | MSE Loss 0.000000
# Iter 1170 | MSE Loss 0.000000
# Iter 1171 | MSE Loss 0.000000
# Iter 1172 | MSE Loss 0.000000
# Iter 1173 | MSE Loss 0.000000
# Iter 1174 | MSE Loss 0.000000
# Iter 1175 | MSE Loss 0.000000
# Iter 1176 | MSE Loss 0.000000
# Iter 1177 | MSE Loss 0.000000
# Iter 1178 | MSE Loss 0.000000
# Iter 1179 | MSE Loss 0.000000
# Iter 1180 | MSE Loss 0.000000
# Iter 1181 | MSE Loss 0.000000
# Iter 1182 | MSE Loss 0.000000
# Iter 1183 | MSE Loss 0.000000
# Iter 1184 | MSE Loss 0.000000
# Iter 1185 | MSE Loss 0.000000
# Iter 1186 | MSE Loss 0.000000
# Iter 1187 | MSE Loss 0.000000
# Iter 1188 | MSE Loss 0.000000
# Iter 1189 | MSE Loss 0.000000
# Iter 1190 | MSE Loss 0.000000
# Iter 1191 | MSE Loss 0.000000
# Iter 1192 | MSE Loss 0.000000
# Iter 1193 | MSE Loss 0.000000
# Iter 1194 | MSE Loss 0.000000
# Iter 1195 | MSE Loss 0.000000
# Iter 1196 | MSE Loss 0.000000
# Iter 1197 | MSE Loss 0.000000
# Iter 1198 | MSE Loss 0.000000
# Iter 1199 | MSE Loss 0.000000
# Iter 1200 | MSE Loss 0.000000
# Iter 1201 | MSE Loss 0.000000
# Iter 1202 | MSE Loss 0.000000
# Iter 1203 | MSE Loss 0.000000
# Iter 1204 | MSE Loss 0.000000
# Iter 1205 | MSE Loss 0.000000
# Iter 1206 | MSE Loss 0.000000
# Iter 1207 | MSE Loss 0.000000
# Iter 1208 | MSE Loss 0.000000
# Iter 1209 | MSE Loss 0.000000
# Iter 1210 | MSE Loss 0.000000
# Iter 1211 | MSE Loss 0.000000
# Iter 1212 | MSE Loss 0.000000
# Iter 1213 | MSE Loss 0.000000
# Iter 1214 | MSE Loss 0.000000
# Iter 1215 | MSE Loss 0.000000
# Iter 1216 | MSE Loss 0.000000
# Iter 1217 | MSE Loss 0.000000
# Iter 1218 | MSE Loss 0.000000
# Iter 1219 | MSE Loss 0.000000
# Iter 1220 | MSE Loss 0.000000
# Iter 1221 | MSE Loss 0.000000
# Iter 1222 | MSE Loss 0.000000
# Iter 1223 | MSE Loss 0.000000
# Iter 1224 | MSE Loss 0.000000
# Iter 1225 | MSE Loss 0.000000
# Iter 1226 | MSE Loss 0.000000
# Iter 1227 | MSE Loss 0.000000
# Iter 1228 | MSE Loss 0.000000
# Iter 1229 | MSE Loss 0.000000
# Iter 1230 | MSE Loss 0.000000
# Iter 1231 | MSE Loss 0.000000
# Iter 1232 | MSE Loss 0.000000
# Iter 1233 | MSE Loss 0.000000
# Iter 1234 | MSE Loss 0.000000
# Iter 1235 | MSE Loss 0.000000
# Iter 1236 | MSE Loss 0.000000
# Iter 1237 | MSE Loss 0.000000
# Iter 1238 | MSE Loss 0.000000
# Iter 1239 | MSE Loss 0.000000
# Iter 1240 | MSE Loss 0.000000
# Iter 1241 | MSE Loss 0.000000
# Iter 1242 | MSE Loss 0.000000
# Iter 1243 | MSE Loss 0.000000
# Iter 1244 | MSE Loss 0.000000
# Iter 1245 | MSE Loss 0.000000
# Iter 1246 | MSE Loss 0.000000
# Iter 1247 | MSE Loss 0.000000
# Iter 1248 | MSE Loss 0.000000
# Iter 1249 | MSE Loss 0.000000
# Iter 1250 | MSE Loss 0.000000
# Iter 1251 | MSE Loss 0.000000
# Iter 1252 | MSE Loss 0.000000
# Iter 1253 | MSE Loss 0.000000
# Iter 1254 | MSE Loss 0.000000
# Iter 1255 | MSE Loss 0.000000
# Iter 1256 | MSE Loss 0.000000
# Iter 1257 | MSE Loss 0.000000
# Iter 1258 | MSE Loss 0.000000
# Iter 1259 | MSE Loss 0.000000
# Iter 1260 | MSE Loss 0.000000
# Iter 1261 | MSE Loss 0.000000
# Iter 1262 | MSE Loss 0.000000
# Iter 1263 | MSE Loss 0.000000
# Iter 1264 | MSE Loss 0.000000
# Iter 1265 | MSE Loss 0.000000
# Iter 1266 | MSE Loss 0.000000
# Iter 1267 | MSE Loss 0.000000
# Iter 1268 | MSE Loss 0.000000
# Iter 1269 | MSE Loss 0.000000
# Iter 1270 | MSE Loss 0.000000
# Iter 1271 | MSE Loss 0.000000
# Iter 1272 | MSE Loss 0.000000
# Iter 1273 | MSE Loss 0.000000
# Iter 1274 | MSE Loss 0.000000
# Iter 1275 | MSE Loss 0.000000
# Iter 1276 | MSE Loss 0.000000
# Iter 1277 | MSE Loss 0.000000
# Iter 1278 | MSE Loss 0.000000
# Iter 1279 | MSE Loss 0.000000
# Iter 1280 | MSE Loss 0.000000
# Iter 1281 | MSE Loss 0.000000
# Iter 1282 | MSE Loss 0.000000
# Iter 1283 | MSE Loss 0.000000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 50
#      47 optimizer = optim.Adam(func.parameters(), lr=1e-5)
#      49 for itr in range(1, 2001):
# ---> 50     pred_y = odeint(func, true_y0, t, method='rk4').to(device)
#      51     loss = nn.MSELoss()(pred_y, true_y)
#      53     optimizer.zero_grad()
#
# File /opt/homebrew/lib/python3.13/site-packages/torchdiffeq/_impl/odeint.py:80, in odeint(func, y0, t, rtol, atol, method, options, event_fn)
#      77 solver = SOLVERS[method](func=func, y0=y0, rtol=rtol, atol=atol, **options)
#      79 if event_fn is None:
# ---> 80     solution = solver.integrate(t)
#      81 else:
#      82     event_t, solution = solver.integrate_until_event(t[0], event_fn)
#
# File /opt/homebrew/lib/python3.13/site-packages/torchdiffeq/_impl/solvers.py:114, in FixedGridODESolver.integrate(self, t)
#     112 dt = t1 - t0
#     113 self.func.callback_step(t0, y0, dt)
# --> 114 dy, f0 = self._step_func(self.func, t0, dt, t1, y0)
#     115 y1 = y0 + dy
#     117 while j < len(t) and t1 >= t[j]:
#
# File /opt/homebrew/lib/python3.13/site-packages/torchdiffeq/_impl/fixed_grid.py:29, in RK4._step_func(self, func, t0, dt, t1, y0)
#      27 def _step_func(self, func, t0, dt, t1, y0):
#      28     f0 = func(t0, y0, perturb=Perturb.NEXT if self.perturb else Perturb.NONE)
# ---> 29     return rk4_alt_step_func(func, t0, dt, t1, y0, f0=f0, perturb=self.perturb), f0
#
# File /opt/homebrew/lib/python3.13/site-packages/torchdiffeq/_impl/rk_common.py:113, in rk4_alt_step_func(func, t0, dt, t1, y0, f0, perturb)
#     111 if k1 is None:
#     112     k1 = func(t0, y0, perturb=Perturb.NEXT if perturb else Perturb.NONE)
# --> 113 k2 = func(t0 + dt * _one_third, y0 + dt * k1 * _one_third)
#     114 k3 = func(t0 + dt * _two_thirds, y0 + dt * (k2 - k1 * _one_third))
#     115 k4 = func(t1, y0 + dt * (k1 - k2 + k3), perturb=Perturb.PREV if perturb else Perturb.NONE)
#
# File /opt/homebrew/lib/python3.13/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /opt/homebrew/lib/python3.13/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File /opt/homebrew/lib/python3.13/site-packages/torchdiffeq/_impl/misc.py:197, in _PerturbFunc.forward(self, t, y, perturb)
#     194 else:
#     195     # Do nothing.
#     196     pass
# --> 197 return self.base_func(t, y)
#
# File /opt/homebrew/lib/python3.13/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /opt/homebrew/lib/python3.13/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# Cell In[14], line 41, in ODEFunc.forward(self, t, y)
#      40 def forward(self, t, y):
# ---> 41     return self.net(y)
#
# File /opt/homebrew/lib/python3.13/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /opt/homebrew/lib/python3.13/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File /opt/homebrew/lib/python3.13/site-packages/torch/nn/modules/container.py:250, in Sequential.forward(self, input)
#     248 def forward(self, input):
#     249     for module in self:
# --> 250         input = module(input)
#     251     return input
#
# KeyboardInterrupt:
